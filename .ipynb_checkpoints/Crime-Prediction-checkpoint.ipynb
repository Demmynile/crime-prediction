# %% [markdown]
# # CRIME PREDICTION WITH MACHINE LEARNING

# %% [markdown]
# ### 0.0 Libraries Needed

# %%
# import operating system library
import os
# data manipulation library
import pandas as pd

# numerical analysis library
import numpy as np

# data visualization library
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.0 Data Acquisition

# %% [markdown]
# ### Target Data from Police Data Uk

# %%
# acquiring the dataset from the source and showing a little brief of its details.
data_2022_1 = pd.read_csv("./data/2022-01/2022-01-humberside-street.csv")
data_2022_1
# Out:
#                                                Crime ID    Month  \
# 0     36947a3b5ab7d934131d410c34ab26c519a8c4b8282c2a...  2022-01
# 1                                                   NaN  2022-01
# 2     83144b441ac439b3eacdf1d76f540912e4cac4e3d930c1...  2022-01
# 3     13d9478ab66f4e24039f1b8e9c5978802fc246c864177a...  2022-01
# 4     6a7d368b7e973b021bea99a9600b6c3226452dad860bc2...  2022-01
# ...                                                 ...      ...
# 7996  8f3cc5353731e74853664423046147fbb16e483abd717a...  2022-01
# 7997  db68742f82d85a1d83fa7f8b7351bc842baa0d9b59962b...  2022-01
# 7998  b550a2f20d2729aae02bb058a085d68ddee551a695b955...  2022-01
# 7999  e59bfce81e2360146322b3d8d0a6ecc580989c48daf626...  2022-01
# 8000  899140f2792ff39e213c2a002b6a91c4ce3ef51088abd2...  2022-01
#
#             Reported by       Falls within  Longitude   Latitude  \
# 0     Humberside Police  Humberside Police  -1.468574  53.531548
# 1     Humberside Police  Humberside Police  -1.466500  54.469116
# 2     Humberside Police  Humberside Police  -0.957546  53.657785
# 3     Humberside Police  Humberside Police  -0.951286  53.606369
# 4     Humberside Police  Humberside Police  -0.215495  54.110420
# ...                 ...                ...        ...        ...
# 7996  Humberside Police  Humberside Police  -0.777385  53.491719
# 7997  Humberside Police  Humberside Police  -0.753623  53.555646
# 7998  Humberside Police  Humberside Police  -0.781282  53.494042
# 7999  Humberside Police  Humberside Police  -0.776328  53.490189
# 8000  Humberside Police  Humberside Police  -0.693031  54.008829
#
#                               Location  LSOA code  \
# 0             On or near Thomas Street  E01007463
# 1             On or near Sockburn Lane  E01012338
# 2     On or near Johnny Moor Long Lane  E01007632
# 3              On or near Fenland Road  E01007642
# 4          On or near Scarborough Road  E01012934
# ...                                ...        ...
# 7996           On or near Croft'S Lane  E01013253
# 7997                   On or near M180  E01013253
# 7998          On or near Gashouse Lane  E01013253
# 7999          On or near Silver Street  E01013253
# 8000            On or near Pefham Lane  E01027803
#
#                           LSOA name                    Crime type  \
# 0                     Barnsley 021F                   Other crime
# 1                   Darlington 015A         Anti-social behaviour
# 2                    Doncaster 001A     Criminal damage and arson
# 3                    Doncaster 003G                   Other crime
# 4     East Riding of Yorkshire 001B     Criminal damage and arson
# ...                             ...                           ...
# 7996        North Lincolnshire 023D                 Vehicle crime
# 7997        North Lincolnshire 023D  Violence and sexual offences
# 7998        North Lincolnshire 023D  Violence and sexual offences
# 7999        North Lincolnshire 023D  Violence and sexual offences
# 8000                   Ryedale 004D                      Burglary
#
#                               Last outcome category  Context
# 0        Action to be taken by another organisation      NaN
# 1                                               NaN      NaN
# 2     Investigation complete; no suspect identified      NaN
# 3                       Unable to prosecute suspect      NaN
# 4     Investigation complete; no suspect identified      NaN
# ...                                             ...      ...
# 7996  Investigation complete; no suspect identified      NaN
# 7997  Investigation complete; no suspect identified      NaN
# 7998                    Unable to prosecute suspect      NaN
# 7999                    Unable to prosecute suspect      NaN
# 8000  Investigation complete; no suspect identified      NaN
#
# [8001 rows x 12 columns]

# %%
data_2022_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8001 entries, 0 to 8000
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               7071 non-null   object
#  1   Month                  8001 non-null   object
#  2   Reported by            8001 non-null   object
#  3   Falls within           8001 non-null   object
#  4   Longitude              8001 non-null   float64
#  5   Latitude               8001 non-null   float64
#  6   Location               8001 non-null   object
#  7   LSOA code              8001 non-null   object
#  8   LSOA name              8001 non-null   object
#  9   Crime type             8001 non-null   object
#  10  Last outcome category  7071 non-null   object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 750.2+ KB

# %%
data_2022_1.dtypes
# Out:
# Crime ID                  object
# Month                     object
# Reported by               object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# Location                  object
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# Context                  float64
# dtype: object

# %%
data_2022_1.shape
# Out:
# (8001, 12)

# %% [markdown]
# ### Loop through to combine all Police data together

# %%
# write a function that can loop through the csv files in a folder with the same data format and concatenate them together.

def concatenate_csv_files_in_subfolders(main_folder_path):
   
    df_list = []

    for root, _, files in os.walk(main_folder_path):
        for file in files:
            if file.endswith('.csv'):
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                df_list.append(df)

    concatenated_df = pd.concat(df_list, ignore_index=True)
    return concatenated_df

# Example usage
main_folder_path = './data'
police_df = concatenate_csv_files_in_subfolders(main_folder_path)
police_df
# Out:
#         Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                                 E01000001            City of London 001A
# 1                                 E01000001            City of London 001A
# 2                                 E01000001            City of London 001A
# 3                                 E01000001            City of London 001A
# 4                                 E01000001            City of London 001A
# ...                                     ...                            ...
# 6246691                                 NaN                            NaN
# 6246692                                 NaN                            NaN
# 6246693                                 NaN                            NaN
# 6246694                                 NaN                            NaN
# 6246695                                 NaN                            NaN
#
#          Age (6 categories) Code       Age (6 categories)  \
# 0                            1.0  Aged 15 years and under
# 1                            1.0  Aged 15 years and under
# 2                            1.0  Aged 15 years and under
# 3                            1.0  Aged 15 years and under
# 4                            1.0  Aged 15 years and under
# ...                          ...                      ...
# 6246691                      NaN                      NaN
# 6246692                      NaN                      NaN
# 6246693                      NaN                      NaN
# 6246694                      NaN                      NaN
# 6246695                      NaN                      NaN
#
#          Economic activity status (7 categories) Code  \
# 0                                                -8.0
# 1                                                -8.0
# 2                                                 1.0
# 3                                                 1.0
# 4                                                 2.0
# ...                                               ...
# 6246691                                           NaN
# 6246692                                           NaN
# 6246693                                           NaN
# 6246694                                           NaN
# 6246695                                           NaN
#
#                    Economic activity status (7 categories)  \
# 0                                           Does not apply
# 1                                           Does not apply
# 2        Economically active (excluding full-time stude...
# 3        Economically active (excluding full-time stude...
# 4        Economically active (excluding full-time stude...
# ...                                                    ...
# 6246691                                                NaN
# 6246692                                                NaN
# 6246693                                                NaN
# 6246694                                                NaN
# 6246695                                                NaN
#
#          Sex (2 categories) Code Sex (2 categories)  Observation  \
# 0                            1.0             Female         58.0
# 1                            2.0               Male         64.0
# 2                            1.0             Female          0.0
# 3                            2.0               Male          0.0
# 4                            1.0             Female          0.0
# ...                          ...                ...          ...
# 6246691                      NaN                NaN          NaN
# 6246692                      NaN                NaN          NaN
# 6246693                      NaN                NaN          NaN
# 6246694                      NaN                NaN          NaN
# 6246695                      NaN                NaN          NaN
#
#          Ethnic group (20 categories) Code  ...        Reported by  \
# 0                                      NaN  ...                NaN
# 1                                      NaN  ...                NaN
# 2                                      NaN  ...                NaN
# 3                                      NaN  ...                NaN
# 4                                      NaN  ...                NaN
# ...                                    ...  ...                ...
# 6246691                                NaN  ...  Humberside Police
# 6246692                                NaN  ...  Humberside Police
# 6246693                                NaN  ...  Humberside Police
# 6246694                                NaN  ...  Humberside Police
# 6246695                                NaN  ...  Humberside Police
#
#               Falls within Longitude   Latitude  \
# 0                      NaN       NaN        NaN
# 1                      NaN       NaN        NaN
# 2                      NaN       NaN        NaN
# 3                      NaN       NaN        NaN
# 4                      NaN       NaN        NaN
# ...                    ...       ...        ...
# 6246691  Humberside Police -0.746565  53.543158
# 6246692  Humberside Police -0.780693  53.492517
# 6246693  Humberside Police -0.775559  53.486019
# 6246694  Humberside Police -0.751275  53.543118
# 6246695  Humberside Police -0.763280  53.501376
#
#                                           Location  LSOA code  \
# 0                                              NaN        NaN
# 1                                              NaN        NaN
# 2                                              NaN        NaN
# 3                                              NaN        NaN
# 4                                              NaN        NaN
# ...                                            ...        ...
# 6246691            On or near Christopher'S Meadow  E01013253
# 6246692                On or near Temperton'S Lane  E01013253
# 6246693                    On or near South Street  E01013253
# 6246694  On or near Park View Terrace Paddock Lane  E01013253
# 6246695                    On or near Parking Area  E01013253
#
#                        LSOA name                    Crime type  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 6246691  North Lincolnshire 023D  Violence and sexual offences
# 6246692  North Lincolnshire 023D  Violence and sexual offences
# 6246693  North Lincolnshire 023D  Violence and sexual offences
# 6246694  North Lincolnshire 023D  Violence and sexual offences
# 6246695  North Lincolnshire 023D  Violence and sexual offences
#
#                                  Last outcome category Context
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4                                                  NaN     NaN
# ...                                                ...     ...
# 6246691                    Unable to prosecute suspect     NaN
# 6246692                    Unable to prosecute suspect     NaN
# 6246693                    Unable to prosecute suspect     NaN
# 6246694                      Status update unavailable     NaN
# 6246695  Investigation complete; no suspect identified     NaN
#
# [6246696 rows x 25 columns]

# %%
police_df["LSOA name"].unique()
# Out:
# array([nan, 'Barnet 024E', 'Copeland 004F', 'Doncaster 006F',
#        'Doncaster 008D', 'Doncaster 030C', 'East Lindsey 001E',
#        'East Lindsey 005C', 'East Riding of Yorkshire 001A',
#        'East Riding of Yorkshire 001B', 'East Riding of Yorkshire 001D',
#        'East Riding of Yorkshire 001E', 'East Riding of Yorkshire 001F',
#        'East Riding of Yorkshire 001G', 'East Riding of Yorkshire 002A',
#        'East Riding of Yorkshire 002B', 'East Riding of Yorkshire 002C',
#        'East Riding of Yorkshire 002D', 'East Riding of Yorkshire 002E',
#        'East Riding of Yorkshire 003A', 'East Riding of Yorkshire 003B',
#        'East Riding of Yorkshire 003C', 'East Riding of Yorkshire 003D',
#        'East Riding of Yorkshire 003E', 'East Riding of Yorkshire 004A',
#        'East Riding of Yorkshire 004B', 'East Riding of Yorkshire 004C',
#        'East Riding of Yorkshire 004D', 'East Riding of Yorkshire 005A',
#        'East Riding of Yorkshire 005B', 'East Riding of Yorkshire 005C',
#        'East Riding of Yorkshire 005D', 'East Riding of Yorkshire 006A',
#        'East Riding of Yorkshire 006B', 'East Riding of Yorkshire 006C',
#        'East Riding of Yorkshire 006D', 'East Riding of Yorkshire 008A',
#        'East Riding of Yorkshire 008B', 'East Riding of Yorkshire 008C',
#        'East Riding of Yorkshire 008D', 'East Riding of Yorkshire 008E',
#        'East Riding of Yorkshire 009A', 'East Riding of Yorkshire 009B',
#        'East Riding of Yorkshire 009C', 'East Riding of Yorkshire 009D',
#        'East Riding of Yorkshire 009E', 'East Riding of Yorkshire 010A',
#        'East Riding of Yorkshire 010B', 'East Riding of Yorkshire 010C',
#        'East Riding of Yorkshire 010D', 'East Riding of Yorkshire 011B',
#        'East Riding of Yorkshire 011C', 'East Riding of Yorkshire 011D',
#        'East Riding of Yorkshire 011E', 'East Riding of Yorkshire 011F',
#        'East Riding of Yorkshire 011G', 'East Riding of Yorkshire 011H',
#        'East Riding of Yorkshire 011I', 'East Riding of Yorkshire 012A',
#        'East Riding of Yorkshire 012B', 'East Riding of Yorkshire 012C',
#        'East Riding of Yorkshire 012D', 'East Riding of Yorkshire 012E',
#        'East Riding of Yorkshire 013A', 'East Riding of Yorkshire 013B',
#        'East Riding of Yorkshire 013C', 'East Riding of Yorkshire 013D',
#        'East Riding of Yorkshire 014A', 'East Riding of Yorkshire 014B',
#        'East Riding of Yorkshire 014C', 'East Riding of Yorkshire 015A',
#        'East Riding of Yorkshire 015B', 'East Riding of Yorkshire 015C',
#        'East Riding of Yorkshire 015D', 'East Riding of Yorkshire 016A',
#        'East Riding of Yorkshire 016B', 'East Riding of Yorkshire 016C',
#        'East Riding of Yorkshire 016D', 'East Riding of Yorkshire 016E',
#        'East Riding of Yorkshire 017A', 'East Riding of Yorkshire 017B',
#        'East Riding of Yorkshire 017C', 'East Riding of Yorkshire 017D',
#        'East Riding of Yorkshire 018A', 'East Riding of Yorkshire 018B',
#        'East Riding of Yorkshire 018C', 'East Riding of Yorkshire 018D',
#        'East Riding of Yorkshire 018E', 'East Riding of Yorkshire 019A',
#        'East Riding of Yorkshire 019B', 'East Riding of Yorkshire 019C',
#        'East Riding of Yorkshire 019D', 'East Riding of Yorkshire 019E',
#        'East Riding of Yorkshire 019F', 'East Riding of Yorkshire 020A',
#        'East Riding of Yorkshire 020B', 'East Riding of Yorkshire 020C',
#        'East Riding of Yorkshire 020D', 'East Riding of Yorkshire 020E',
#        'East Riding of Yorkshire 020F', 'East Riding of Yorkshire 021A',
#        'East Riding of Yorkshire 021B', 'East Riding of Yorkshire 021C',
#        'East Riding of Yorkshire 021D', 'East Riding of Yorkshire 021E',
#        'East Riding of Yorkshire 022A', 'East Riding of Yorkshire 022B',
#        'East Riding of Yorkshire 022D', 'East Riding of Yorkshire 022E',
#        'East Riding of Yorkshire 023A', 'East Riding of Yorkshire 023B',
#        'East Riding of Yorkshire 023C', 'East Riding of Yorkshire 023D',
#        'East Riding of Yorkshire 023E', 'East Riding of Yorkshire 024C',
#        'East Riding of Yorkshire 024D', 'East Riding of Yorkshire 024E',
#        'East Riding of Yorkshire 024F', 'East Riding of Yorkshire 025A',
#        'East Riding of Yorkshire 025B', 'East Riding of Yorkshire 025C',
#        'East Riding of Yorkshire 025D', 'East Riding of Yorkshire 026A',
#        'East Riding of Yorkshire 026B', 'East Riding of Yorkshire 026C',
#        'East Riding of Yorkshire 026D', 'East Riding of Yorkshire 026E',
#        'East Riding of Yorkshire 027A', 'East Riding of Yorkshire 027B',
#        'East Riding of Yorkshire 027C', 'East Riding of Yorkshire 027D',
#        'East Riding of Yorkshire 027E', 'East Riding of Yorkshire 028A',
#        'East Riding of Yorkshire 028B', 'East Riding of Yorkshire 028C',
#        'East Riding of Yorkshire 028D', 'East Riding of Yorkshire 028E',
#        'East Riding of Yorkshire 029A', 'East Riding of Yorkshire 029B',
#        'East Riding of Yorkshire 029C', 'East Riding of Yorkshire 029D',
#        'East Riding of Yorkshire 029E', 'East Riding of Yorkshire 031A',
#        'East Riding of Yorkshire 031B', 'East Riding of Yorkshire 031C',
#        'East Riding of Yorkshire 031D', 'East Riding of Yorkshire 031E',
#        'East Riding of Yorkshire 032A', 'East Riding of Yorkshire 032C',
#        'East Riding of Yorkshire 032E', 'East Riding of Yorkshire 032F',
#        'East Riding of Yorkshire 032G', 'East Riding of Yorkshire 032H',
#        'East Riding of Yorkshire 032I', 'East Riding of Yorkshire 032J',
#        'East Riding of Yorkshire 033A', 'East Riding of Yorkshire 033B',
#        'East Riding of Yorkshire 033C', 'East Riding of Yorkshire 033D',
#        'East Riding of Yorkshire 033E', 'East Riding of Yorkshire 034A',
#        'East Riding of Yorkshire 034B', 'East Riding of Yorkshire 034C',
#        'East Riding of Yorkshire 034D', 'East Riding of Yorkshire 034E',
#        'East Riding of Yorkshire 035A', 'East Riding of Yorkshire 035B',
#        'East Riding of Yorkshire 035C', 'East Riding of Yorkshire 035D',
#        'East Riding of Yorkshire 035E', 'East Riding of Yorkshire 036A',
#        'East Riding of Yorkshire 036B', 'East Riding of Yorkshire 036C',
#        'East Riding of Yorkshire 036D', 'East Riding of Yorkshire 037A',
#        'East Riding of Yorkshire 037B', 'East Riding of Yorkshire 037C',
#        'East Riding of Yorkshire 037D', 'East Riding of Yorkshire 038A',
#        'East Riding of Yorkshire 038B', 'East Riding of Yorkshire 038C',
#        'East Riding of Yorkshire 039A', 'East Riding of Yorkshire 039B',
#        'East Riding of Yorkshire 039C', 'East Riding of Yorkshire 039D',
#        'East Riding of Yorkshire 039E', 'East Riding of Yorkshire 039F',
#        'East Riding of Yorkshire 040A', 'East Riding of Yorkshire 040B',
#        'East Riding of Yorkshire 040C', 'East Riding of Yorkshire 040D',
#        'East Riding of Yorkshire 040E', 'East Riding of Yorkshire 041A',
#        'East Riding of Yorkshire 041B', 'East Riding of Yorkshire 041C',
#        'East Riding of Yorkshire 041D', 'East Riding of Yorkshire 041E',
#        'East Riding of Yorkshire 042A', 'East Riding of Yorkshire 042B',
#        'East Riding of Yorkshire 042C', 'East Riding of Yorkshire 042D',
#        'East Riding of Yorkshire 043A', 'East Riding of Yorkshire 043B',
#        'East Riding of Yorkshire 043C', 'East Riding of Yorkshire 043D',
#        'East Riding of Yorkshire 043E', 'East Riding of Yorkshire 043F',
#        'East Riding of Yorkshire 044A', 'East Riding of Yorkshire 044C',
#        'East Riding of Yorkshire 044D', 'East Riding of Yorkshire 044E',
#        'East Riding of Yorkshire 044F', 'East Riding of Yorkshire 045A',
#        'East Riding of Yorkshire 045B', 'East Riding of Yorkshire 045C',
#        'East Riding of Yorkshire 045D', 'Hinckley and Bosworth 001G',
#        'Hinckley and Bosworth 007B', 'Kingston upon Hull 002A',
#        'Kingston upon Hull 002B', 'Kingston upon Hull 002C',
#        'Kingston upon Hull 002D', 'Kingston upon Hull 002E',
#        'Kingston upon Hull 002F', 'Kingston upon Hull 003A',
#        'Kingston upon Hull 003B', 'Kingston upon Hull 003C',
#        'Kingston upon Hull 003D', 'Kingston upon Hull 003E',
#        'Kingston upon Hull 004A', 'Kingston upon Hull 004B',
#        'Kingston upon Hull 004C', 'Kingston upon Hull 004D',
#        'Kingston upon Hull 004E', 'Kingston upon Hull 004F',
#        'Kingston upon Hull 005A', 'Kingston upon Hull 005B',
#        'Kingston upon Hull 005C', 'Kingston upon Hull 005D',
#        'Kingston upon Hull 006A', 'Kingston upon Hull 006B',
#        'Kingston upon Hull 006C', 'Kingston upon Hull 006D',
#        'Kingston upon Hull 006E', 'Kingston upon Hull 007A',
#        'Kingston upon Hull 007B', 'Kingston upon Hull 007C',
#        'Kingston upon Hull 007D', 'Kingston upon Hull 007E',
#        'Kingston upon Hull 008A', 'Kingston upon Hull 008B',
#        'Kingston upon Hull 008C', 'Kingston upon Hull 008D',
#        'Kingston upon Hull 008E', 'Kingston upon Hull 008F',
#        'Kingston upon Hull 008G', 'Kingston upon Hull 009A',
#        'Kingston upon Hull 009B', 'Kingston upon Hull 009C',
#        'Kingston upon Hull 009D', 'Kingston upon Hull 009E',
#        'Kingston upon Hull 010A', 'Kingston upon Hull 010B',
#        'Kingston upon Hull 010C', 'Kingston upon Hull 010D',
#        'Kingston upon Hull 010E', 'Kingston upon Hull 011A',
#        'Kingston upon Hull 011D', 'Kingston upon Hull 011E',
#        'Kingston upon Hull 011F', 'Kingston upon Hull 012A',
#        'Kingston upon Hull 012B', 'Kingston upon Hull 012C',
#        'Kingston upon Hull 012D', 'Kingston upon Hull 013A',
#        'Kingston upon Hull 013B', 'Kingston upon Hull 013D',
#        'Kingston upon Hull 013E', 'Kingston upon Hull 014A',
#        'Kingston upon Hull 014B', 'Kingston upon Hull 014C',
#        'Kingston upon Hull 014D', 'Kingston upon Hull 014E',
#        'Kingston upon Hull 015A', 'Kingston upon Hull 015B',
#        'Kingston upon Hull 015C', 'Kingston upon Hull 015D',
#        'Kingston upon Hull 015E', 'Kingston upon Hull 016A',
#        'Kingston upon Hull 016B', 'Kingston upon Hull 016C',
#        'Kingston upon Hull 016D', 'Kingston upon Hull 016E',
#        'Kingston upon Hull 017A', 'Kingston upon Hull 017B',
#        'Kingston upon Hull 017C', 'Kingston upon Hull 017F',
#        'Kingston upon Hull 017G', 'Kingston upon Hull 018A',
#        'Kingston upon Hull 018B', 'Kingston upon Hull 018C',
#        'Kingston upon Hull 018D', 'Kingston upon Hull 018E',
#        'Kingston upon Hull 019A', 'Kingston upon Hull 019B',
#        'Kingston upon Hull 019C', 'Kingston upon Hull 019D',
#        'Kingston upon Hull 019E', 'Kingston upon Hull 020A',
#        'Kingston upon Hull 020B', 'Kingston upon Hull 020C',
#        'Kingston upon Hull 020D', 'Kingston upon Hull 020E',
#        'Kingston upon Hull 021A', 'Kingston upon Hull 021B',
#        'Kingston upon Hull 021C', 'Kingston upon Hull 021D',
#        'Kingston upon Hull 021E', 'Kingston upon Hull 022A',
#        'Kingston upon Hull 022B', 'Kingston upon Hull 022C',
#        'Kingston upon Hull 022D', 'Kingston upon Hull 022E',
#        'Kingston upon Hull 023A', 'Kingston upon Hull 023B',
#        'Kingston upon Hull 023C', 'Kingston upon Hull 023D',
#        'Kingston upon Hull 023E', 'Kingston upon Hull 024A',
#        'Kingston upon Hull 024B', 'Kingston upon Hull 024C',
#        'Kingston upon Hull 024D', 'Kingston upon Hull 024E',
#        'Kingston upon Hull 025A', 'Kingston upon Hull 025B',
#        'Kingston upon Hull 025C', 'Kingston upon Hull 025D',
#        'Kingston upon Hull 025E', 'Kingston upon Hull 026A',
#        'Kingston upon Hull 026B', 'Kingston upon Hull 026C',
#        'Kingston upon Hull 026D', 'Kingston upon Hull 026E',
#        'Kingston upon Hull 027A', 'Kingston upon Hull 027B',
#        'Kingston upon Hull 027C', 'Kingston upon Hull 027D',
#        'Kingston upon Hull 027E', 'Kingston upon Hull 028A',
#        'Kingston upon Hull 028B', 'Kingston upon Hull 028C',
#        'Kingston upon Hull 028D', 'Kingston upon Hull 028E',
#        'Kingston upon Hull 029C', 'Kingston upon Hull 029D',
#        'Kingston upon Hull 029E', 'Kingston upon Hull 029F',
#        'Kingston upon Hull 029G', 'Kingston upon Hull 029H',
#        'Kingston upon Hull 030A', 'Kingston upon Hull 030B',
#        'Kingston upon Hull 030C', 'Kingston upon Hull 030D',
#        'Kingston upon Hull 030E', 'Kingston upon Hull 031A',
#        'Kingston upon Hull 031B', 'Kingston upon Hull 031D',
#        'Kingston upon Hull 031E', 'Kingston upon Hull 031H',
#        'Kingston upon Hull 031I', 'Kingston upon Hull 033A',
#        'Kingston upon Hull 033B', 'Kingston upon Hull 033C',
#        'Kingston upon Hull 033D', 'Kingston upon Hull 033E',
#        'Kingston upon Hull 034A', 'Kingston upon Hull 034B',
#        'Kingston upon Hull 034C', 'Kingston upon Hull 034D',
#        'Kingston upon Hull 034E', 'Kingston upon Hull 035A',
#        'Kingston upon Hull 035B', 'Kingston upon Hull 035C',
#        'Kingston upon Hull 035D', 'Kingston upon Hull 035E', 'Leeds 111E',
#        'Maidstone 006C', 'North East Lincolnshire 001A',
#        'North East Lincolnshire 001B', 'North East Lincolnshire 001C',
#        'North East Lincolnshire 001D', 'North East Lincolnshire 001E',
#        'North East Lincolnshire 001F', 'North East Lincolnshire 001G',
#        'North East Lincolnshire 002A', 'North East Lincolnshire 002D',
#        'North East Lincolnshire 002E', 'North East Lincolnshire 003A',
#        'North East Lincolnshire 003B', 'North East Lincolnshire 003C',
#        'North East Lincolnshire 003D', 'North East Lincolnshire 003E',
#        'North East Lincolnshire 004A', 'North East Lincolnshire 004B',
#        'North East Lincolnshire 004C', 'North East Lincolnshire 004D',
#        'North East Lincolnshire 005A', 'North East Lincolnshire 005B',
#        'North East Lincolnshire 005C', 'North East Lincolnshire 005D',
#        'North East Lincolnshire 005E', 'North East Lincolnshire 006A',
#        'North East Lincolnshire 006B', 'North East Lincolnshire 006C',
#        'North East Lincolnshire 006D', 'North East Lincolnshire 007A',
#        'North East Lincolnshire 007C', 'North East Lincolnshire 007D',
#        'North East Lincolnshire 007E', 'North East Lincolnshire 007F',
#        'North East Lincolnshire 008A', 'North East Lincolnshire 008B',
#        'North East Lincolnshire 008C', 'North East Lincolnshire 008D',
#        'North East Lincolnshire 009A', 'North East Lincolnshire 009D',
#        'North East Lincolnshire 009E', 'North East Lincolnshire 011A',
#        'North East Lincolnshire 011B', 'North East Lincolnshire 011C',
#        'North East Lincolnshire 011D', 'North East Lincolnshire 012A',
#        'North East Lincolnshire 012B', 'North East Lincolnshire 012C',
#        'North East Lincolnshire 012D', 'North East Lincolnshire 012E',
#        'North East Lincolnshire 013A', 'North East Lincolnshire 013B',
#        'North East Lincolnshire 013C', 'North East Lincolnshire 013D',
#        'North East Lincolnshire 013E', 'North East Lincolnshire 014A',
#        'North East Lincolnshire 014B', 'North East Lincolnshire 014C',
#        'North East Lincolnshire 014D', 'North East Lincolnshire 015A',
#        'North East Lincolnshire 015B', 'North East Lincolnshire 015C',
#        'North East Lincolnshire 015D', 'North East Lincolnshire 016A',
#        'North East Lincolnshire 016B', 'North East Lincolnshire 016C',
#        'North East Lincolnshire 016D', 'North East Lincolnshire 016E',
#        'North East Lincolnshire 016F', 'North East Lincolnshire 018A',
#        'North East Lincolnshire 018B', 'North East Lincolnshire 018C',
#        'North East Lincolnshire 018D', 'North East Lincolnshire 019A',
#        'North East Lincolnshire 019B', 'North East Lincolnshire 019C',
#        'North East Lincolnshire 019D', 'North East Lincolnshire 019E',
#        'North East Lincolnshire 020A', 'North East Lincolnshire 020B',
#        'North East Lincolnshire 020D', 'North East Lincolnshire 020F',
#        'North East Lincolnshire 021A', 'North East Lincolnshire 021C',
#        'North East Lincolnshire 021D', 'North East Lincolnshire 021E',
#        'North East Lincolnshire 021F', 'North East Lincolnshire 021G',
#        'North East Lincolnshire 022B', 'North East Lincolnshire 022C',
#        'North East Lincolnshire 022D', 'North East Lincolnshire 022E',
#        'North East Lincolnshire 022F', 'North East Lincolnshire 022G',
#        'North East Lincolnshire 023A', 'North East Lincolnshire 023B',
#        'North East Lincolnshire 023C', 'North East Lincolnshire 023D',
#        'North East Lincolnshire 023E', 'North East Lincolnshire 023F',
#        'North East Lincolnshire 024A', 'North East Lincolnshire 024B',
#        'North East Lincolnshire 024C', 'North East Lincolnshire 024D',
#        'North East Lincolnshire 024E', 'North East Lincolnshire 024F',
#        'North East Lincolnshire 024G', 'North East Lincolnshire 024H',
#        'North Lincolnshire 001A', 'North Lincolnshire 001B',
#        'North Lincolnshire 001C', 'North Lincolnshire 001D',
#        'North Lincolnshire 001E', 'North Lincolnshire 001F',
#        'North Lincolnshire 002A', 'North Lincolnshire 002B',
#        'North Lincolnshire 002C', 'North Lincolnshire 002D',
#        'North Lincolnshire 003A', 'North Lincolnshire 003B',
#        'North Lincolnshire 003C', 'North Lincolnshire 003D',
#        'North Lincolnshire 004A', 'North Lincolnshire 004B',
#        'North Lincolnshire 004C', 'North Lincolnshire 004D',
#        'North Lincolnshire 005A', 'North Lincolnshire 005B',
#        'North Lincolnshire 005C', 'North Lincolnshire 005D',
#        'North Lincolnshire 005E', 'North Lincolnshire 006A',
#        'North Lincolnshire 006B', 'North Lincolnshire 006C',
#        'North Lincolnshire 006D', 'North Lincolnshire 006E',
#        'North Lincolnshire 007A', 'North Lincolnshire 007B',
#        'North Lincolnshire 007C', 'North Lincolnshire 007D',
#        'North Lincolnshire 008A', 'North Lincolnshire 008B',
#        'North Lincolnshire 008C', 'North Lincolnshire 008D',
#        'North Lincolnshire 008E', 'North Lincolnshire 009A',
#        'North Lincolnshire 009B', 'North Lincolnshire 009C',
#        'North Lincolnshire 009D', 'North Lincolnshire 010A',
#        'North Lincolnshire 010B', 'North Lincolnshire 010C',
#        'North Lincolnshire 010D', 'North Lincolnshire 011A',
#        'North Lincolnshire 011B', 'North Lincolnshire 011C',
#        'North Lincolnshire 011D', 'North Lincolnshire 011E',
#        'North Lincolnshire 011F', 'North Lincolnshire 012A',
#        'North Lincolnshire 012B', 'North Lincolnshire 012C',
#        'North Lincolnshire 012D', 'North Lincolnshire 013A',
#        'North Lincolnshire 013B', 'North Lincolnshire 013C',
#        'North Lincolnshire 013D', 'North Lincolnshire 014A',
#        'North Lincolnshire 014B', 'North Lincolnshire 014C',
#        'North Lincolnshire 014D', 'North Lincolnshire 015A',
#        'North Lincolnshire 015C', 'North Lincolnshire 015D',
#        'North Lincolnshire 015E', 'North Lincolnshire 015F',
#        'North Lincolnshire 015G', 'North Lincolnshire 016A',
#        'North Lincolnshire 016B', 'North Lincolnshire 016C',
#        'North Lincolnshire 016D', 'North Lincolnshire 017A',
#        'North Lincolnshire 017B', 'North Lincolnshire 017C',
#        'North Lincolnshire 017D', 'North Lincolnshire 018B',
#        'North Lincolnshire 018C', 'North Lincolnshire 018D',
#        'North Lincolnshire 018E', 'North Lincolnshire 018F',
#        'North Lincolnshire 018G', 'North Lincolnshire 019A',
#        'North Lincolnshire 019B', 'North Lincolnshire 019C',
#        'North Lincolnshire 019D', 'North Lincolnshire 020A',
#        'North Lincolnshire 020B', 'North Lincolnshire 020C',
#        'North Lincolnshire 020D', 'North Lincolnshire 021A',
#        'North Lincolnshire 021B', 'North Lincolnshire 021C',
#        'North Lincolnshire 021D', 'North Lincolnshire 022A',
#        'North Lincolnshire 022B', 'North Lincolnshire 022C',
#        'North Lincolnshire 022D', 'North Lincolnshire 023A',
#        'North Lincolnshire 023B', 'North Lincolnshire 023C',
#        'North Lincolnshire 023D', 'Ryedale 004D', 'Scarborough 014E',
#        'Selby 010B', 'South Kesteven 003D', 'West Lindsey 001A',
#        'West Lindsey 001G', 'West Lindsey 002C', 'West Lindsey 005B',
#        'West Lindsey 005D', 'York 024F', 'Barnsley 010I',
#        'Bassetlaw 002D', 'Blackpool 006A', 'Bradford 012C',
#        'Calderdale 013C', 'Dacorum 018F', 'Doncaster 001B',
#        'Doncaster 003B', 'East Lindsey 001D', 'East Lindsey 005B',
#        'East Riding of Yorkshire 001H', 'East Riding of Yorkshire 014D',
#        'East Riding of Yorkshire 016F', 'East Riding of Yorkshire 022C',
#        'East Riding of Yorkshire 038D', 'Kingston upon Hull 013C',
#        'Leeds 054B', 'Lincoln 004F', 'Manchester 039C',
#        'North Northamptonshire 021E', 'Rushmoor 006C', 'Selby 008C',
#        'West Lindsey 002B', 'West Lindsey 003A', 'York 018E', 'York 019B',
#        'Birmingham 134A', 'Calderdale 017C', 'Chesterfield 002D',
#        'Dartford 002C', 'Doncaster 008A', 'Doncaster 034A',
#        'East Lindsey 001A', 'East Lindsey 001C', 'East Lindsey 007C',
#        'Hambleton 009B', 'Rochdale 018C', 'Rotherham 013A', 'Selby 004D',
#        'Swansea 007B', 'Swansea 009A', 'Swansea 029B',
#        'West Lindsey 004C', 'West Lindsey 004F', 'Wyre 004C', 'York 001C',
#        'York 010B', 'Bassetlaw 012B', 'Bradford 009B',
#        'Cheshire West and Chester 046A', 'Doncaster 004A',
#        'Doncaster 037E', 'East Lindsey 001F', 'East Lindsey 008A',
#        'East Riding of Yorkshire 001C', 'East Riding of Yorkshire 011A',
#        'East Riding of Yorkshire 024A', 'East Riding of Yorkshire 024B',
#        'East Riding of Yorkshire 032D', 'East Riding of Yorkshire 044B',
#        'Kingston upon Hull 001A', 'Kingston upon Hull 001B',
#        'Kingston upon Hull 001C', 'Kingston upon Hull 001E',
#        'Kingston upon Hull 001F', 'Kingston upon Hull 001G',
#        'Kingston upon Hull 001H', 'Kingston upon Hull 001I',
#        'Kingston upon Hull 011B', 'Kingston upon Hull 011C',
#        'Kingston upon Hull 017D', 'Kingston upon Hull 017E',
#        'Kingston upon Hull 029A', 'Kingston upon Hull 031G', 'Leeds 111B',
#        'Leeds 111C', 'Leicester 004B', 'Medway 022C',
#        'Newark and Sherwood 003A', 'North East Lincolnshire 002B',
#        'North East Lincolnshire 002C', 'North East Lincolnshire 007B',
#        'North East Lincolnshire 010A', 'North East Lincolnshire 010B',
#        'North East Lincolnshire 010C', 'North East Lincolnshire 010D',
#        'North East Lincolnshire 017A', 'North East Lincolnshire 017B',
#        'North East Lincolnshire 017C', 'North East Lincolnshire 017D',
#        'North East Lincolnshire 020C', 'North East Lincolnshire 020E',
#        'North East Lincolnshire 021B', 'North East Lincolnshire 022A',
#        'North Lincolnshire 015B', 'Rotherham 017B', 'Selby 005E',
#        'Selby 007D', 'West Lindsey 001C', 'West Lindsey 009C',
#        'Wrexham 008F', 'York 013A', 'Birmingham 081C', 'Doncaster 014F',
#        'Doncaster 015E', 'Doncaster 028D', 'East Lindsey 004A',
#        'East Northamptonshire 008E', 'Leeds 071D', 'Rotherham 009D',
#        'Ryedale 007E', 'Scarborough 007D', 'Scarborough 014B',
#        'Selby 010D', 'Bassetlaw 003A', 'Doncaster 003E', 'Doncaster 024B',
#        'Doncaster 036A', 'Doncaster 005C', 'West Lindsey 002D',
#        'Bassetlaw 001D', 'Calderdale 007C', 'County Durham 052D',
#        'Doncaster 007E', 'Doncaster 014D', 'Doncaster 022A',
#        'Doncaster 034C', 'East Lindsey 016D', 'Kirklees 038D',
#        'Leeds 109E', 'Melton 002D', 'Ryedale 004B', 'Ryedale 003D',
#        'West Lindsey 003E', 'West Lindsey 006C', 'Birmingham 023C',
#        'Cheshire West and Chester 025A', 'Doncaster 023B',
#        'Doncaster 027E', 'Doncaster 028A', 'Doncaster 028B',
#        'Middlesbrough 003E', 'North East Derbyshire 012B',
#        'Scarborough 014G', 'Shropshire 033A', 'Barnsley 026E',
#        'Basingstoke and Deane 004B', 'Central Bedfordshire 022A',
#        'Colchester 007D', 'Doncaster 013D', 'Gateshead 026C',
#        'Newcastle upon Tyne 024C', 'Stockton-on-Tees 014F',
#        'West Lindsey 002E', 'York 007C', 'Central Bedfordshire 009G',
#        'Doncaster 022E', 'East Lindsey 016B', 'Kirklees 025A',
#        'Leeds 044D', 'Leicester 020E', 'Lincoln 005A', 'Lincoln 010D',
#        'Rotherham 033D', 'Salford 003C', 'Scarborough 009F',
#        'Scarborough 012A', 'Tameside 028F', 'Tonbridge and Malling 011E',
#        'Worcester 004B', 'York 015E', 'York 016B', 'York 020A',
#        'Barnsley 007E', 'Birmingham 094E', 'Doncaster 003C',
#        'Doncaster 018C', 'East Lindsey 001B', 'Eden 006B',
#        'Northumberland 035B', 'Poole 004D', 'Richmondshire 004H',
#        'Scarborough 010A', 'Sheffield 030A', 'Stevenage 002D',
#        'Crawley 001C', 'Doncaster 022G', 'Doncaster 035A',
#        'East Lindsey 004D', 'East Lindsey 013E', 'Kirklees 049C',
#        'Leeds 064B', 'Mansfield 005C', 'North Hertfordshire 003B',
#        'North Kesteven 005E', 'Rotherham 026B', 'Sefton 009C',
#        'Selby 005G', 'South Kesteven 016G', 'Southwark 002B',
#        'Wolverhampton 033D', 'Barnsley 020A', 'Boston 003D', 'Brent 023C',
#        'Melton 004D', 'Scarborough 010D', 'Scarborough 013A',
#        'Sheffield 042G', 'South Oxfordshire 012E', 'Thurrock 001C',
#        'West Lindsey 001D', 'Barnet 022C', 'Bradford 044F',
#        'Doncaster 008B', 'Doncaster 015D', 'Doncaster 026A',
#        'Doncaster 028C', 'East Lindsey 010D', 'Leicester 031A',
#        'Scarborough 014A', 'Selby 003C', 'Selby 010A', 'Selby 010C',
#        'Southampton 025D', 'Thurrock 006D', 'West Lindsey 001B',
#        'York 014B', 'Amber Valley 011C', 'Ashford 004A',
#        'Aylesbury Vale 006D', 'Doncaster 010A', 'Doncaster 013A',
#        'East Lindsey 002B', 'East Lindsey 004E', 'Scarborough 014D',
#        'Stockport 026B', 'Barnsley 021F', 'Darlington 015A',
#        'Doncaster 001A', 'Doncaster 003G', 'Bradford 026C', 'Derby 024E',
#        'Leeds 069A', 'Leeds 090E', 'Lincoln 003A', 'Oldham 014B',
#        'Richmondshire 004E', 'Scarborough 011A', 'Selby 008E',
#        'Sheffield 026A', 'Thurrock 017D', 'West Lindsey 011A',
#        'Bradford 046D', 'Leeds 050C', 'Leeds 076D', 'North Kesteven 003G',
#        'Rotherham 011A', 'Ryedale 002D', 'Ryedale 007A', 'Sheffield 045E',
#        'Vale of White Horse 005C', 'West Lindsey 004E', 'Bradford 011D',
#        'Bradford 020D', 'Doncaster 018F', 'East Lindsey 001G',
#        'Kirklees 053D', 'Ryedale 008C', 'Sandwell 039E', 'Selby 005C',
#        'Selby 005D', 'Wakefield 011A', 'Wakefield 026E',
#        'Barrow-in-Furness 004B', 'Blackpool 014E', 'Hambleton 013B',
#        'Kirklees 006B', 'Leeds 079E', 'Scarborough 009B',
#        'Sheffield 054A', 'Wakefield 001C', 'Barnsley 006D',
#        'Cheshire East 005C', 'Doncaster 011B', 'Doncaster 015C',
#        'Lincoln 005F', 'Liverpool 058C', 'Scarborough 004F',
#        'Sheffield 073C', 'Surrey Heath 005E', 'Three Rivers 002A',
#        'Walsall 002A', 'Warwick 002E', 'Wolverhampton 035A', 'York 021C',
#        'Barnsley 011A', 'Lincoln 002C', 'Manchester 062A', 'Rugby 008D',
#        'Rugby 013D', 'Sheffield 019B', 'South Holland 003C', 'York 002B',
#        'York 024E'], dtype=object)

# %%
police_df["Crime type"].unique()
# Out:
# array([nan, 'Violence and sexual offences', 'Criminal damage and arson',
#        'Robbery', 'Anti-social behaviour', 'Other theft', 'Shoplifting',
#        'Other crime', 'Burglary', 'Public order', 'Drugs',
#        'Possession of weapons', 'Vehicle crime', 'Bicycle theft',
#        'Theft from the person'], dtype=object)

# %% [markdown]
# ### Filter out the crime type to be property type and lsoa name to be kingston upon hull

# %%
police_df = police_df[police_df['Crime type'] ==  'Burglary']
police_df
# Out:
#         Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 2999353                                 NaN                            NaN
# 2999357                                 NaN                            NaN
# 2999358                                 NaN                            NaN
# 2999395                                 NaN                            NaN
# 2999431                                 NaN                            NaN
# ...                                     ...                            ...
# 6246607                                 NaN                            NaN
# 6246625                                 NaN                            NaN
# 6246626                                 NaN                            NaN
# 6246649                                 NaN                            NaN
# 6246671                                 NaN                            NaN
#
#          Age (6 categories) Code Age (6 categories)  \
# 2999353                      NaN                NaN
# 2999357                      NaN                NaN
# 2999358                      NaN                NaN
# 2999395                      NaN                NaN
# 2999431                      NaN                NaN
# ...                          ...                ...
# 6246607                      NaN                NaN
# 6246625                      NaN                NaN
# 6246626                      NaN                NaN
# 6246649                      NaN                NaN
# 6246671                      NaN                NaN
#
#          Economic activity status (7 categories) Code  \
# 2999353                                           NaN
# 2999357                                           NaN
# 2999358                                           NaN
# 2999395                                           NaN
# 2999431                                           NaN
# ...                                               ...
# 6246607                                           NaN
# 6246625                                           NaN
# 6246626                                           NaN
# 6246649                                           NaN
# 6246671                                           NaN
#
#         Economic activity status (7 categories)  Sex (2 categories) Code  \
# 2999353                                     NaN                      NaN
# 2999357                                     NaN                      NaN
# 2999358                                     NaN                      NaN
# 2999395                                     NaN                      NaN
# 2999431                                     NaN                      NaN
# ...                                         ...                      ...
# 6246607                                     NaN                      NaN
# 6246625                                     NaN                      NaN
# 6246626                                     NaN                      NaN
# 6246649                                     NaN                      NaN
# 6246671                                     NaN                      NaN
#
#         Sex (2 categories)  Observation  Ethnic group (20 categories) Code  \
# 2999353                NaN          NaN                                NaN
# 2999357                NaN          NaN                                NaN
# 2999358                NaN          NaN                                NaN
# 2999395                NaN          NaN                                NaN
# 2999431                NaN          NaN                                NaN
# ...                    ...          ...                                ...
# 6246607                NaN          NaN                                NaN
# 6246625                NaN          NaN                                NaN
# 6246626                NaN          NaN                                NaN
# 6246649                NaN          NaN                                NaN
# 6246671                NaN          NaN                                NaN
#
#          ...        Reported by       Falls within Longitude   Latitude  \
# 2999353  ...  Humberside Police  Humberside Police -0.198602  54.099921
# 2999357  ...  Humberside Police  Humberside Police -0.204431  54.105887
# 2999358  ...  Humberside Police  Humberside Police -0.204431  54.105887
# 2999395  ...  Humberside Police  Humberside Police -0.112521  54.124598
# 2999431  ...  Humberside Police  Humberside Police -0.207805  54.093281
# ...      ...                ...                ...       ...        ...
# 6246607  ...  Humberside Police  Humberside Police -0.829907  53.527589
# 6246625  ...  Humberside Police  Humberside Police -0.608331  53.550376
# 6246626  ...  Humberside Police  Humberside Police -0.578668  53.552239
# 6246649  ...  Humberside Police  Humberside Police -0.584908  53.472857
# 6246671  ...  Humberside Police  Humberside Police -0.933315  53.524178
#
#                            Location  LSOA code                      LSOA name  \
# 2999353   On or near Balmoral Close  E01012941  East Riding of Yorkshire 001F
# 2999357   On or near Eleanor Avenue  E01034752  East Riding of Yorkshire 001G
# 2999358   On or near Eleanor Avenue  E01034752  East Riding of Yorkshire 001G
# 2999395   On or near Thornwick Road  E01012937  East Riding of Yorkshire 002D
# 2999431      On or near High Street  E01012931  East Riding of Yorkshire 003B
# ...                             ...        ...                            ...
# 6246607    On or near Nicholson Way  E01013243        North Lincolnshire 020C
# 6246625       On or near Holme Lane  E01013324        North Lincolnshire 021A
# 6246626  On or near Mortal Ash Hill  E01013324        North Lincolnshire 021A
# 6246649        On or near Mill Lane  E01013323        North Lincolnshire 022B
# 6246671        On or near Sand Lane  E01013251        North Lincolnshire 023B
#
#          Crime type                          Last outcome category Context
# 2999353    Burglary  Investigation complete; no suspect identified     NaN
# 2999357    Burglary  Investigation complete; no suspect identified     NaN
# 2999358    Burglary                      Status update unavailable     NaN
# 2999395    Burglary                      Status update unavailable     NaN
# 2999431    Burglary  Investigation complete; no suspect identified     NaN
# ...             ...                                            ...     ...
# 6246607    Burglary                    Unable to prosecute suspect     NaN
# 6246625    Burglary  Investigation complete; no suspect identified     NaN
# 6246626    Burglary  Investigation complete; no suspect identified     NaN
# 6246649    Burglary  Investigation complete; no suspect identified     NaN
# 6246671    Burglary  Investigation complete; no suspect identified     NaN
#
# [12684 rows x 25 columns]

# %%
 # Filtering the dataframe to include only rows where 'Leeds' appears in 'LSOA name'
police_df = police_df[police_df['LSOA name'].str.contains('Hull')]
police_df
# Out:
#         Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 3001375                                 NaN                            NaN
# 3001390                                 NaN                            NaN
# 3001415                                 NaN                            NaN
# 3001416                                 NaN                            NaN
# 3001417                                 NaN                            NaN
# ...                                     ...                            ...
# 6243359                                 NaN                            NaN
# 6243372                                 NaN                            NaN
# 6243373                                 NaN                            NaN
# 6243374                                 NaN                            NaN
# 6243375                                 NaN                            NaN
#
#          Age (6 categories) Code Age (6 categories)  \
# 3001375                      NaN                NaN
# 3001390                      NaN                NaN
# 3001415                      NaN                NaN
# 3001416                      NaN                NaN
# 3001417                      NaN                NaN
# ...                          ...                ...
# 6243359                      NaN                NaN
# 6243372                      NaN                NaN
# 6243373                      NaN                NaN
# 6243374                      NaN                NaN
# 6243375                      NaN                NaN
#
#          Economic activity status (7 categories) Code  \
# 3001375                                           NaN
# 3001390                                           NaN
# 3001415                                           NaN
# 3001416                                           NaN
# 3001417                                           NaN
# ...                                               ...
# 6243359                                           NaN
# 6243372                                           NaN
# 6243373                                           NaN
# 6243374                                           NaN
# 6243375                                           NaN
#
#         Economic activity status (7 categories)  Sex (2 categories) Code  \
# 3001375                                     NaN                      NaN
# 3001390                                     NaN                      NaN
# 3001415                                     NaN                      NaN
# 3001416                                     NaN                      NaN
# 3001417                                     NaN                      NaN
# ...                                         ...                      ...
# 6243359                                     NaN                      NaN
# 6243372                                     NaN                      NaN
# 6243373                                     NaN                      NaN
# 6243374                                     NaN                      NaN
# 6243375                                     NaN                      NaN
#
#         Sex (2 categories)  Observation  Ethnic group (20 categories) Code  \
# 3001375                NaN          NaN                                NaN
# 3001390                NaN          NaN                                NaN
# 3001415                NaN          NaN                                NaN
# 3001416                NaN          NaN                                NaN
# 3001417                NaN          NaN                                NaN
# ...                    ...          ...                                ...
# 6243359                NaN          NaN                                NaN
# 6243372                NaN          NaN                                NaN
# 6243373                NaN          NaN                                NaN
# 6243374                NaN          NaN                                NaN
# 6243375                NaN          NaN                                NaN
#
#          ...        Reported by       Falls within Longitude   Latitude  \
# 3001375  ...  Humberside Police  Humberside Police -0.335230  53.788680
# 3001390  ...  Humberside Police  Humberside Police -0.334913  53.794761
# 3001415  ...  Humberside Police  Humberside Police -0.321360  53.787408
# 3001416  ...  Humberside Police  Humberside Police -0.321537  53.786413
# 3001417  ...  Humberside Police  Humberside Police -0.322720  53.789863
# ...      ...                ...                ...       ...        ...
# 6243359  ...  Humberside Police  Humberside Police -0.349460  53.801282
# 6243372  ...  Humberside Police  Humberside Police -0.341493  53.798071
# 6243373  ...  Humberside Police  Humberside Police -0.346269  53.794557
# 6243374  ...  Humberside Police  Humberside Police -0.347889  53.795045
# 6243375  ...  Humberside Police  Humberside Police -0.342161  53.800013
#
#                              Location  LSOA code                LSOA name  \
# 3001375    On or near Davidstow Close  E01012785  Kingston upon Hull 002B
# 3001390       On or near Malpas Close  E01012786  Kingston upon Hull 002C
# 3001415           On or near Hospital  E01012787  Kingston upon Hull 002D
# 3001416      On or near Shopping Area  E01012787  Kingston upon Hull 002D
# 3001417      On or near Dalwood Close  E01012787  Kingston upon Hull 002D
# ...                               ...        ...                      ...
# 6243359        On or near Parish Mews  E01035471  Kingston upon Hull 035B
# 6243372  On or near Ferry Meadow Park  E01033105  Kingston upon Hull 035D
# 6243373        On or near Supermarket  E01033105  Kingston upon Hull 035D
# 6243374      On or near Shopping Area  E01033105  Kingston upon Hull 035D
# 6243375      On or near Saltwell Park  E01033105  Kingston upon Hull 035D
#
#          Crime type                          Last outcome category Context
# 3001375    Burglary  Investigation complete; no suspect identified     NaN
# 3001390    Burglary  Investigation complete; no suspect identified     NaN
# 3001415    Burglary  Investigation complete; no suspect identified     NaN
# 3001416    Burglary                    Unable to prosecute suspect     NaN
# 3001417    Burglary  Investigation complete; no suspect identified     NaN
# ...             ...                                            ...     ...
# 6243359    Burglary                    Unable to prosecute suspect     NaN
# 6243372    Burglary  Investigation complete; no suspect identified     NaN
# 6243373    Burglary  Investigation complete; no suspect identified     NaN
# 6243374    Burglary  Investigation complete; no suspect identified     NaN
# 6243375    Burglary  Investigation complete; no suspect identified     NaN
#
# [5516 rows x 25 columns]

# %%
# getting the shape of the dataframe
police_df.shape
# Out:
# (5516, 25)

# %%
# getting the information of this data including the data types 
police_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5516 entries, 3001375 to 6243375
# Data columns (total 25 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Lower layer Super Output Areas Code           0 non-null      object
#  1   Lower layer Super Output Areas                0 non-null      object
#  2   Age (6 categories) Code                       0 non-null      float64
#  3   Age (6 categories)                            0 non-null      object
#  4   Economic activity status (7 categories) Code  0 non-null      float64
#  5   Economic activity status (7 categories)       0 non-null      object
#  6   Sex (2 categories) Code                       0 non-null      float64
#  7   Sex (2 categories)                            0 non-null      object
#  8   Observation                                   0 non-null      float64
#  9   Ethnic group (20 categories) Code             0 non-null      float64
#  10  Ethnic group (20 categories)                  0 non-null      object
#  11  Country of birth (13 categories) Code         0 non-null      float64
#  12  Country of birth (13 categories)              0 non-null      object
#  13  Crime ID                                      5516 non-null   object
#  14  Month                                         5516 non-null   object
#  15  Reported by                                   5516 non-null   object
#  16  Falls within                                  5516 non-null   object
#  17  Longitude                                     5516 non-null   float64
#  18  Latitude                                      5516 non-null   float64
#  19  Location                                      5516 non-null   object
#  20  LSOA code                                     5516 non-null   object
#  21  LSOA name                                     5516 non-null   object
#  22  Crime type                                    5516 non-null   object
#  23  Last outcome category                         5516 non-null   object
#  24  Context                                       0 non-null      float64
# dtypes: float64(9), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# ### INDEPENDENT FEATURES DATA COLLECTION

# %%
#!pip3 install geopandas --break-system-packages

# %%
# importing geopandas library we will dealing with more of geographic features now!
import geopandas as gpd

# %% [markdown]
# ## Open Street Map Data Collection

# %% [markdown]
# ### Buildings

# %%
osm_data = gpd.read_file('./data/hull-shapefile/gis_osm_buildings_a_free_1.shp')
osm_data
# Out:
#             osm_id  code    fclass         name         type  \
# 0          5935388  1500  building         Asda        store
# 1          8761733  1500  building  Sainsbury's  supermarket
# 2         14368870  1500  building          B&Q         None
# 3         14368871  1500  building         None        block
# 4         14368872  1500  building        Makro         None
# ...            ...   ...       ...          ...          ...
# 200925  1291055193  1500  building         None        house
# 200926  1291055194  1500  building         None        house
# 200927  1291055195  1500  building         None        house
# 200928  1291055196  1500  building         None        house
# 200929  1291055197  1500  building         None        house
#
#                                                  geometry
# 0       POLYGON ((-0.37397 53.73364, -0.37379 53.73365...
# 1       POLYGON ((-0.42159 53.72325, -0.42004 53.72366...
# 2       POLYGON ((-0.38144 53.72608, -0.38115 53.72615...
# 3       POLYGON ((-0.37882 53.72691, -0.37770 53.72717...
# 4       POLYGON ((-0.38465 53.72560, -0.38345 53.72586...
# ...                                                   ...
# 200925  POLYGON ((-0.26984 53.83763, -0.26974 53.83767...
# 200926  POLYGON ((-0.26968 53.83769, -0.26958 53.83772...
# 200927  POLYGON ((-0.26955 53.83774, -0.26945 53.83777...
# 200928  POLYGON ((-0.26938 53.83779, -0.26929 53.83783...
# 200929  POLYGON ((-0.26924 53.83783, -0.26915 53.83786...
#
# [200930 rows x 6 columns]

# %% [markdown]
# ### Point Of Interest

# %%
osm_poi = gpd.read_file('./data/hull-shapefile/gis_osm_pois_a_free_1.shp')
osm_poi
# Out:
#           osm_id  code            fclass                           name  \
# 0        4214242  2733    archaeological  Archbishop's Palace (site of)
# 1        4389769  2961  wastewater_plant              Bishop Wilton/STW
# 2        5935388  2501       supermarket                           Asda
# 3        7849820  2255       golf_course         Springhead Golf Course
# 4        7850857  2255       golf_course                 Hull Golf Club
# ...          ...   ...               ...                            ...
# 3379  1290444496  2252             pitch                           None
# 3380  1290444497  2252             pitch                           None
# 3381  1290444498  2252             pitch                           None
# 3382  1290444499  2258             track                           None
# 3383  1290444500  2252             pitch                           None
#
#                                                geometry
# 0     POLYGON ((-0.78228 53.98828, -0.78208 53.98839...
# 1     POLYGON ((-0.79347 53.97946, -0.79292 53.98013...
# 2     POLYGON ((-0.37397 53.73364, -0.37379 53.73365...
# 3     POLYGON ((-0.42917 53.75845, -0.42774 53.75864...
# 4     POLYGON ((-0.46986 53.75491, -0.46957 53.75494...
# ...                                                 ...
# 3379  POLYGON ((-0.19331 53.75254, -0.19257 53.75260...
# 3380  POLYGON ((-0.19486 53.75167, -0.19427 53.75171...
# 3381  POLYGON ((-0.19496 53.75077, -0.19413 53.75083...
# 3382  POLYGON ((-0.19227 53.75142, -0.19225 53.75147...
# 3383  POLYGON ((-0.19456 53.75276, -0.19358 53.75283...
#
# [3384 rows x 5 columns]

# %% [markdown]
# ### Merging all data needed from OSM

# %% [markdown]
# ### Check all the plots available

# %%
import glob

# %%
# Define the folder containing the shapefiles
folder_path = './data/hull-shapefile'

# Find all shapefiles in the folder
shapefiles = glob.glob(os.path.join(folder_path, '*.shp'))

# Load each shapefile into a GeoDataFrame and check for empty geometries
gdfs = []
for shp in shapefiles:
    gdf = gpd.read_file(shp)
    if not gdf.empty and gdf.geometry.notnull().all():
        gdfs.append(gdf)

# Ensure all GeoDataFrames have the same CRS
if gdfs:
    common_crs = gdfs[0].crs
    gdfs = [gdf.to_crs(common_crs) for gdf in gdfs]

    # Visualize the geometries
    for i, gdf in enumerate(gdfs):
        gdf.plot()
        plt.title(f'Shapefile {i}')
        plt.show()

# %% [markdown]
# ### Merging all the shapefiles together

# %%
osm_df = gpd.read_file('./data/hull-shapefile')
osm_df
# Out:
#            osm_id  code             fclass                          name  \
# 0         3282540  7214             quarry                          None
# 1         3282573  7201             forest                     Crow Wood
# 2         3419230  7207         allotments                          None
# 3         3419231  7211  recreation_ground  Bishop Wilton Playing Fields
# 4         6180385  7214             quarry          Melton Bottom Quarry
# ...           ...   ...                ...                           ...
# 37926  1289640324  7218              grass                          None
# 37927  1289640325  7218              grass                          None
# 37928  1289640326  7218              grass                          None
# 37929  1289640327  7218              grass                          None
# 37930  1289640328  7218              grass                          None
#
#                                                 geometry
# 0      POLYGON ((-0.77468 53.99335, -0.77467 53.99351...
# 1      POLYGON ((-0.77125 53.99053, -0.77105 53.99108...
# 2      POLYGON ((-0.78208 53.98938, -0.78169 53.98946...
# 3      POLYGON ((-0.78458 53.98950, -0.78249 53.98983...
# 4      POLYGON ((-0.53843 53.74003, -0.53757 53.74126...
# ...                                                  ...
# 37926  POLYGON ((-0.19507 53.76706, -0.19505 53.76707...
# 37927  POLYGON ((-0.19468 53.76689, -0.19462 53.76690...
# 37928  POLYGON ((-0.19524 53.76715, -0.19518 53.76719...
# 37929  POLYGON ((-0.19495 53.76716, -0.19476 53.76706...
# 37930  POLYGON ((-0.19512 53.76723, -0.19510 53.76725...
#
# [37931 rows x 5 columns]

# %% [markdown]
# ### Create a point data at the center of the polygon as an extra column

# %%
osm_df['centroid'] = osm_df['geometry'].centroid
osm_df
# Out:
#            osm_id  code             fclass                          name  \
# 0         3282540  7214             quarry                          None
# 1         3282573  7201             forest                     Crow Wood
# 2         3419230  7207         allotments                          None
# 3         3419231  7211  recreation_ground  Bishop Wilton Playing Fields
# 4         6180385  7214             quarry          Melton Bottom Quarry
# ...           ...   ...                ...                           ...
# 37926  1289640324  7218              grass                          None
# 37927  1289640325  7218              grass                          None
# 37928  1289640326  7218              grass                          None
# 37929  1289640327  7218              grass                          None
# 37930  1289640328  7218              grass                          None
#
#                                                 geometry  \
# 0      POLYGON ((-0.77468 53.99335, -0.77467 53.99351...
# 1      POLYGON ((-0.77125 53.99053, -0.77105 53.99108...
# 2      POLYGON ((-0.78208 53.98938, -0.78169 53.98946...
# 3      POLYGON ((-0.78458 53.98950, -0.78249 53.98983...
# 4      POLYGON ((-0.53843 53.74003, -0.53757 53.74126...
# ...                                                  ...
# 37926  POLYGON ((-0.19507 53.76706, -0.19505 53.76707...
# 37927  POLYGON ((-0.19468 53.76689, -0.19462 53.76690...
# 37928  POLYGON ((-0.19524 53.76715, -0.19518 53.76719...
# 37929  POLYGON ((-0.19495 53.76716, -0.19476 53.76706...
# 37930  POLYGON ((-0.19512 53.76723, -0.19510 53.76725...
#
#                         centroid
# 0      POINT (-0.77371 53.99367)
# 1      POINT (-0.77015 53.99116)
# 2      POINT (-0.78150 53.98910)
# 3      POINT (-0.78312 53.98893)
# 4      POINT (-0.53107 53.74029)
# ...                          ...
# 37926  POINT (-0.19487 53.76697)
# 37927  POINT (-0.19462 53.76688)
# 37928  POINT (-0.19516 53.76714)
# 37929  POINT (-0.19487 53.76710)
# 37930  POINT (-0.19509 53.76722)
#
# [37931 rows x 6 columns]

# %% [markdown]
# ### Checking the plot of the OSM DATA

# %%
osm_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Boundary Data

# %% [markdown]
# ### Checking the boundary shapefile on how it looks

# %%
osm_boundary_1km = gpd.read_file('./data/Great_Britain_GRID_shapefile')
osm_boundary_1km
# Out:
#               CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0        1kmE2780N3001    2780000    3001000
# 1        1kmE2780N3002    2780000    3002000
# 2        1kmE2780N3003    2780000    3003000
# 3        1kmE2780N3004    2780000    3004000
# 4        1kmE2780N3005    2780000    3005000
# ...                ...        ...        ...
# 1091779  1kmE3922N3657    3922000    3657000
# 1091780  1kmE3922N3658    3922000    3658000
# 1091781  1kmE3922N3659    3922000    3659000
# 1091782  1kmE3922N3660    3922000    3660000
# 1091783  1kmE3922N3661    3922000    3661000
#
#                                                   geometry
# 0        POLYGON ((2780000.000 3001000.000, 2780000.000...
# 1        POLYGON ((2780000.000 3002000.000, 2780000.000...
# 2        POLYGON ((2780000.000 3003000.000, 2780000.000...
# 3        POLYGON ((2780000.000 3004000.000, 2780000.000...
# 4        POLYGON ((2780000.000 3005000.000, 2780000.000...
# ...                                                    ...
# 1091779  POLYGON ((3922000.000 3657000.000, 3922000.000...
# 1091780  POLYGON ((3922000.000 3658000.000, 3922000.000...
# 1091781  POLYGON ((3922000.000 3659000.000, 3922000.000...
# 1091782  POLYGON ((3922000.000 3660000.000, 3922000.000...
# 1091783  POLYGON ((3922000.000 3661000.000, 3922000.000...
#
# [1091784 rows x 4 columns]

# %%
# Viewing the boundary data
osm_boundary_1km.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Filtering The Boundary for Hull City from the Boundary data

# %%
from shapely.geometry import box

# Step 1: Read the Great Britain GRID shapefile
grids = osm_boundary_1km

# Step 2: Define a bounding box for Hull City (adjust coordinates as needed)
hull_bbox_coords = [507000, 427000, 517000, 437000]  # [minx, miny, maxx, maxy]
hull_bbox = box(*hull_bbox_coords)
hull_bbox_gdf = gpd.GeoDataFrame({'geometry': [hull_bbox]}, crs="EPSG:27700")

# Step 3: Ensure the grids GeoDataFrame has the same CRS as the Hull bounding box
grids = grids.to_crs(hull_bbox_gdf.crs)

# Step 4: Perform the spatial join to filter grids that intersect with Hull City's bounding box
hull_grids = gpd.sjoin(grids, hull_bbox_gdf, how="inner", op="intersects")

# Step 5: Drop the extra columns added by the spatial join
hull_grids = hull_grids.drop(columns=['index_right'])

# Step 6: Save the filtered data to a new shapefile
hull_grids.to_file('path_to_save_hull_grids.shp')

# %%
# acquiring the new hull grid.
hull_grid_data = gpd.read_file('./data/hull_boundary_data')
hull_grid_data
# Out:
#           CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0    1kmE3638N3451    3638000    3451000
# 1    1kmE3638N3452    3638000    3452000
# 2    1kmE3638N3453    3638000    3453000
# 3    1kmE3638N3454    3638000    3454000
# 4    1kmE3639N3451    3639000    3451000
# ..             ...        ...        ...
# 119  1kmE3649N3456    3649000    3456000
# 120  1kmE3649N3457    3649000    3457000
# 121  1kmE3649N3458    3649000    3458000
# 122  1kmE3649N3459    3649000    3459000
# 123  1kmE3650N3459    3650000    3459000
#
#                                               geometry
# 0    POLYGON ((506522.999 426569.543, 506355.757 42...
# 1    POLYGON ((506355.757 427554.000, 506188.500 42...
# 2    POLYGON ((506188.500 428538.456, 506021.228 42...
# 3    POLYGON ((506021.228 429522.910, 505853.940 43...
# 4    POLYGON ((507510.216 426734.959, 507342.971 42...
# ..                                                 ...
# 119  POLYGON ((516545.713 433312.030, 516378.360 43...
# 120  POLYGON ((516378.360 434296.551, 516210.991 43...
# 121  POLYGON ((516210.991 435281.070, 516043.608 43...
# 122  POLYGON ((516043.608 436265.588, 515876.209 43...
# 123  POLYGON ((517030.773 436431.113, 516863.371 43...
#
# [124 rows x 4 columns]

# %%
hull_grid_data["centroid"] = hull_grid_data['geometry'].centroid
hull_grid_data
# Out:
#           CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0    1kmE3638N3451    3638000    3451000
# 1    1kmE3638N3452    3638000    3452000
# 2    1kmE3638N3453    3638000    3453000
# 3    1kmE3638N3454    3638000    3454000
# 4    1kmE3639N3451    3639000    3451000
# ..             ...        ...        ...
# 119  1kmE3649N3456    3649000    3456000
# 120  1kmE3649N3457    3649000    3457000
# 121  1kmE3649N3458    3649000    3458000
# 122  1kmE3649N3459    3649000    3459000
# 123  1kmE3650N3459    3650000    3459000
#
#                                               geometry  \
# 0    POLYGON ((506522.999 426569.543, 506355.757 42...
# 1    POLYGON ((506355.757 427554.000, 506188.500 42...
# 2    POLYGON ((506188.500 428538.456, 506021.228 42...
# 3    POLYGON ((506021.228 429522.910, 505853.940 43...
# 4    POLYGON ((507510.216 426734.959, 507342.971 42...
# ..                                                 ...
# 119  POLYGON ((516545.713 433312.030, 516378.360 43...
# 120  POLYGON ((516378.360 434296.551, 516210.991 43...
# 121  POLYGON ((516210.991 435281.070, 516043.608 43...
# 122  POLYGON ((516043.608 436265.588, 515876.209 43...
# 123  POLYGON ((517030.773 436431.113, 516863.371 43...
#
#                           centroid
# 0    POINT (506932.986 427144.481)
# 1    POINT (506765.735 428128.941)
# 2    POINT (506598.469 429113.399)
# 3    POINT (506431.187 430097.856)
# 4    POINT (507920.200 427309.903)
# ..                             ...
# 119  POINT (516955.624 433887.044)
# 120  POINT (516788.261 434871.568)
# 121  POINT (516620.883 435856.090)
# 122  POINT (516453.491 436840.611)
# 123  POINT (517440.653 437006.141)
#
# [124 rows x 5 columns]

# %%
hull_grid_data.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### LSOA BOUNDARY DATA

# %%
lsoa_geo = gpd.read_file("./data/LSOA_BoundaryData")
lsoa_geo
# Out:
#        lsoa21cd         lsoa21nm  \
# 0     E01011905   Wakefield 028C
# 1     E01011876   Wakefield 007B
# 2     E01034963   Harrogate 008E
# 3     E01011803   Wakefield 011A
# 4     E01011297       Leeds 030B
# ...         ...              ...
# 3350  E01010627    Bradford 038E
# 3351  E01011669       Leeds 110F
# 3352  E01010982  Calderdale 013A
# 3353  E01011810   Wakefield 010D
# 3354  E01007976   Sheffield 051B
#
#                                               label             name  \
# 0     E92000001E12000003E08000036E02002465E01011905   Wakefield 028C
# 1     E92000001E12000003E08000036E02002444E01011876   Wakefield 007B
# 2     E92000001E12000003E07000165E02005768E01034963   Harrogate 008E
# 3     E92000001E12000003E08000036E02002448E01011803   Wakefield 011A
# 4     E92000001E12000003E08000035E02002359E01011297       Leeds 030B
# ...                                             ...              ...
# 3350  E92000001E12000003E08000032E02002220E01010627    Bradford 038E
# 3351  E92000001E12000003E08000035E02006861E01011669       Leeds 110F
# 3352  E92000001E12000003E08000033E02002256E01010982  Calderdale 013A
# 3353  E92000001E12000003E08000036E02002447E01011810   Wakefield 010D
# 3354  E92000001E12000003E08000019E02001661E01007976   Sheffield 051B
#
#                                                geometry
# 0     POLYGON ((431757.944 419643.827, 431759.407 41...
# 1     POLYGON ((435467.062 424661.606, 435468.954 42...
# 2     POLYGON ((425907.594 459285.594, 425930.813 45...
# 3     POLYGON ((448734.559 423385.667, 448737.655 42...
# 4     POLYGON ((442339.406 438083.312, 442357.404 43...
# ...                                                 ...
# 3350  POLYGON ((419277.982 434280.077, 419289.724 43...
# 3351  POLYGON ((429378.157 436146.589, 429381.406 43...
# 3352  POLYGON ((393755.380 425088.107, 393746.166 42...
# 3353  POLYGON ((451735.109 423993.287, 451729.219 42...
# 3354  POLYGON ((435939.594 384974.594, 435968.971 38...
#
# [3355 rows x 5 columns]

# %%
#checking the value counts
lsoa_geo['name'].value_counts()
# Out:
# name
# Wakefield 028C                   1
# Bradford 030E                    1
# Leeds 067I                       1
# East Riding of Yorkshire 034A    1
# Bradford 008D                    1
#                                 ..
# Kingston upon Hull 031E          1
# Barnsley 020G                    1
# Sheffield 062D                   1
# Harrogate 010B                   1
# Sheffield 051B                   1
# Name: count, Length: 3355, dtype: int64

# %%
# Filtering the dataframe to include only rows where 'Leeds' appears in 'LSOA name'
lsoa_hull = lsoa_geo[lsoa_geo['lsoa21nm'].str.contains('Hull')]
lsoa_hull
# Out:
#        lsoa21cd                 lsoa21nm  \
# 109   E01012765  Kingston upon Hull 005B
# 132   E01035463  Kingston upon Hull 011F
# 143   E01012848  Kingston upon Hull 020B
# 204   E01012843  Kingston upon Hull 021B
# 235   E01033104  Kingston upon Hull 029E
# ...         ...                      ...
# 3300  E01012782  Kingston upon Hull 002A
# 3302  E01012767  Kingston upon Hull 012B
# 3308  E01012807  Kingston upon Hull 016C
# 3330  E01012778  Kingston upon Hull 004A
# 3343  E01012786  Kingston upon Hull 002C
#
#                                               label                     name  \
# 109   E92000001E12000003E06000010E02002656E01012765  Kingston upon Hull 005B
# 132   E92000001E12000003E06000010E02002662E01035463  Kingston upon Hull 011F
# 143   E92000001E12000003E06000010E02002671E01012848  Kingston upon Hull 020B
# 204   E92000001E12000003E06000010E02002672E01012843  Kingston upon Hull 021B
# 235   E92000001E12000003E06000010E02002680E01033104  Kingston upon Hull 029E
# ...                                             ...                      ...
# 3300  E92000001E12000003E06000010E02002653E01012782  Kingston upon Hull 002A
# 3302  E92000001E12000003E06000010E02002663E01012767  Kingston upon Hull 012B
# 3308  E92000001E12000003E06000010E02002667E01012807  Kingston upon Hull 016C
# 3330  E92000001E12000003E06000010E02002655E01012778  Kingston upon Hull 004A
# 3343  E92000001E12000003E06000010E02002653E01012786  Kingston upon Hull 002C
#
#                                                geometry
# 109   POLYGON ((508697.250 433210.219, 508696.976 43...
# 132   POLYGON ((512991.624 432451.851, 512989.851 43...
# 143   POLYGON ((514326.000 429934.000, 514293.000 42...
# 204   POLYGON ((514997.781 430940.663, 514988.906 43...
# 235   POLYGON ((509552.000 429169.000, 509558.793 42...
# ...                                                 ...
# 3300  POLYGON ((510338.156 435107.688, 510426.199 43...
# 3302  POLYGON ((508610.197 432267.530, 508615.000 43...
# 3308  POLYGON ((511190.094 431056.156, 511193.125 43...
# 3330  POLYGON ((511544.405 433827.924, 511546.375 43...
# 3343  POLYGON ((510112.000 434675.000, 510115.199 43...
#
# [168 rows x 5 columns]

# %% [markdown]
# ## Census Data Collection

# %% [markdown]
# #### Checking out the data for each of them

# %%
# acquiring the census data
census_data = pd.read_csv('./data/census_data.csv')
census_data
# Out:
#         Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                                 E01000001            City of London 001A
# 1                                 E01000001            City of London 001A
# 2                                 E01000001            City of London 001A
# 3                                 E01000001            City of London 001A
# 4                                 E01000001            City of London 001A
# ...                                     ...                            ...
# 2996443                           W01002040         Vale of Glamorgan 015F
# 2996444                           W01002040         Vale of Glamorgan 015F
# 2996445                           W01002040         Vale of Glamorgan 015F
# 2996446                           W01002040         Vale of Glamorgan 015F
# 2996447                           W01002040         Vale of Glamorgan 015F
#
#          Age (6 categories) Code       Age (6 categories)  \
# 0                              1  Aged 15 years and under
# 1                              1  Aged 15 years and under
# 2                              1  Aged 15 years and under
# 3                              1  Aged 15 years and under
# 4                              1  Aged 15 years and under
# ...                          ...                      ...
# 2996443                        6   Aged 65 years and over
# 2996444                        6   Aged 65 years and over
# 2996445                        6   Aged 65 years and over
# 2996446                        6   Aged 65 years and over
# 2996447                        6   Aged 65 years and over
#
#          Economic activity status (7 categories) Code  \
# 0                                                  -8
# 1                                                  -8
# 2                                                   1
# 3                                                   1
# 4                                                   2
# ...                                               ...
# 2996443                                             4
# 2996444                                             5
# 2996445                                             5
# 2996446                                             6
# 2996447                                             6
#
#                    Economic activity status (7 categories)  \
# 0                                           Does not apply
# 1                                           Does not apply
# 2        Economically active (excluding full-time stude...
# 3        Economically active (excluding full-time stude...
# 4        Economically active (excluding full-time stude...
# ...                                                    ...
# 2996443  Economically active and a full-time student: U...
# 2996444  Economically inactive (excluding full-time stu...
# 2996445  Economically inactive (excluding full-time stu...
# 2996446      Economically inactive and a full-time student
# 2996447      Economically inactive and a full-time student
#
#          Sex (2 categories) Code Sex (2 categories)  Observation
# 0                              1             Female           58
# 1                              2               Male           64
# 2                              1             Female            0
# 3                              2               Male            0
# 4                              1             Female            0
# ...                          ...                ...          ...
# 2996443                        2               Male            0
# 2996444                        1             Female           32
# 2996445                        2               Male           30
# 2996446                        1             Female            0
# 2996447                        2               Male            0
#
# [2996448 rows x 9 columns]

# %%
# acquiring the new census data
new_census_data = pd.read_csv('./data/new_census_data.csv')
new_census_data
# Out:
#      Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                              E01001745                   Hackney 016A
# 1                              E01001745                   Hackney 016A
# 2                              E01001745                   Hackney 016A
# 3                              E01001745                   Hackney 016A
# 4                              E01001745                   Hackney 016A
# ...                                  ...                            ...
# 2855                           W01001695                   Cardiff 036B
# 2856                           W01001695                   Cardiff 036B
# 2857                           W01001695                   Cardiff 036B
# 2858                           W01001695                   Cardiff 036B
# 2859                           W01001695                   Cardiff 036B
#
#       Ethnic group (20 categories) Code  \
# 0                                    -8
# 1                                    -8
# 2                                    -8
# 3                                    -8
# 4                                    -8
# ...                                 ...
# 2855                                 19
# 2856                                 19
# 2857                                 19
# 2858                                 19
# 2859                                 19
#
#                     Ethnic group (20 categories)  \
# 0                                 Does not apply
# 1                                 Does not apply
# 2                                 Does not apply
# 3                                 Does not apply
# 4                                 Does not apply
# ...                                          ...
# 2855  Other ethnic group: Any other ethnic group
# 2856  Other ethnic group: Any other ethnic group
# 2857  Other ethnic group: Any other ethnic group
# 2858  Other ethnic group: Any other ethnic group
# 2859  Other ethnic group: Any other ethnic group
#
#       Country of birth (13 categories) Code  \
# 0                                        -8
# 1                                         1
# 2                                         2
# 3                                         3
# 4                                         4
# ...                                     ...
# 2855                                      8
# 2856                                      9
# 2857                                     10
# 2858                                     11
# 2859                                     12
#
#                     Country of birth (13 categories)  Observation
# 0                                     Does not apply            0
# 1                    Europe: United Kingdom: England            0
# 2           Europe: United Kingdom: Northern Ireland            0
# 3                   Europe: United Kingdom: Scotland            0
# 4                      Europe: United Kingdom: Wales            0
# ...                                              ...          ...
# 2855                            Europe: Other Europe           29
# 2856                                          Africa           15
# 2857                            Middle East and Asia           27
# 2858                  The Americas and the Caribbean           27
# 2859  Antarctica and Oceania (including Australasia)            0
#
# [2860 rows x 7 columns]

# %%
# concatenating the two dataframe
census_df = pd.concat([census_data , new_census_data])
census_df
# Out:
#      Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                              E01000001            City of London 001A
# 1                              E01000001            City of London 001A
# 2                              E01000001            City of London 001A
# 3                              E01000001            City of London 001A
# 4                              E01000001            City of London 001A
# ...                                  ...                            ...
# 2855                           W01001695                   Cardiff 036B
# 2856                           W01001695                   Cardiff 036B
# 2857                           W01001695                   Cardiff 036B
# 2858                           W01001695                   Cardiff 036B
# 2859                           W01001695                   Cardiff 036B
#
#       Age (6 categories) Code       Age (6 categories)  \
# 0                         1.0  Aged 15 years and under
# 1                         1.0  Aged 15 years and under
# 2                         1.0  Aged 15 years and under
# 3                         1.0  Aged 15 years and under
# 4                         1.0  Aged 15 years and under
# ...                       ...                      ...
# 2855                      NaN                      NaN
# 2856                      NaN                      NaN
# 2857                      NaN                      NaN
# 2858                      NaN                      NaN
# 2859                      NaN                      NaN
#
#       Economic activity status (7 categories) Code  \
# 0                                             -8.0
# 1                                             -8.0
# 2                                              1.0
# 3                                              1.0
# 4                                              2.0
# ...                                            ...
# 2855                                           NaN
# 2856                                           NaN
# 2857                                           NaN
# 2858                                           NaN
# 2859                                           NaN
#
#                 Economic activity status (7 categories)  \
# 0                                        Does not apply
# 1                                        Does not apply
# 2     Economically active (excluding full-time stude...
# 3     Economically active (excluding full-time stude...
# 4     Economically active (excluding full-time stude...
# ...                                                 ...
# 2855                                                NaN
# 2856                                                NaN
# 2857                                                NaN
# 2858                                                NaN
# 2859                                                NaN
#
#       Sex (2 categories) Code Sex (2 categories)  Observation  \
# 0                         1.0             Female           58
# 1                         2.0               Male           64
# 2                         1.0             Female            0
# 3                         2.0               Male            0
# 4                         1.0             Female            0
# ...                       ...                ...          ...
# 2855                      NaN                NaN           29
# 2856                      NaN                NaN           15
# 2857                      NaN                NaN           27
# 2858                      NaN                NaN           27
# 2859                      NaN                NaN            0
#
#       Ethnic group (20 categories) Code  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2855                               19.0
# 2856                               19.0
# 2857                               19.0
# 2858                               19.0
# 2859                               19.0
#
#                     Ethnic group (20 categories)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2855  Other ethnic group: Any other ethnic group
# 2856  Other ethnic group: Any other ethnic group
# 2857  Other ethnic group: Any other ethnic group
# 2858  Other ethnic group: Any other ethnic group
# 2859  Other ethnic group: Any other ethnic group
#
#       Country of birth (13 categories) Code  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2855                                    8.0
# 2856                                    9.0
# 2857                                   10.0
# 2858                                   11.0
# 2859                                   12.0
#
#                     Country of birth (13 categories)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2855                            Europe: Other Europe
# 2856                                          Africa
# 2857                            Middle East and Asia
# 2858                  The Americas and the Caribbean
# 2859  Antarctica and Oceania (including Australasia)
#
# [2999308 rows x 13 columns]

# %% [markdown]
# ### DIGIMAP AERIAL DATA

# %%
digimap_data_new = gpd.read_file('./data/hull-digital-aerial-data')
digimap_data_new
# Out:
#                                       NAME AREA_CODE      DESCRIPTIO  \
# 0             East Midlands English Region        ER  English Region
# 1                    London English Region        ER  English Region
# 2                North West English Region        ER  English Region
# 3             West Midlands English Region        ER  English Region
# 4  Yorkshire and the Humber English Region        ER  English Region
# 5                South East English Region        ER  English Region
# 6                North East English Region        ER  English Region
# 7                   Eastern English Region        ER  English Region
# 8                South West English Region        ER  English Region
#
#                                  FILE_NAME  NUMBER  NUMBER0  POLYGON_ID  \
# 0             EAST_MIDLANDS_ENGLISH_REGION    2072     2072      124952
# 1                    LONDON_ENGLISH_REGION    2073     2073      124433
# 2                NORTH_WEST_ENGLISH_REGION    2074     2074      126756
# 3             WEST_MIDLANDS_ENGLISH_REGION    2568     2568      125096
# 4  YORKSHIRE_AND_THE_HUMBER_ENGLISH_REGION    2569     2569      124954
# 5                SOUTH_EAST_ENGLISH_REGION    2570     2570       70735
# 6                NORTH_EAST_ENGLISH_REGION    2571     2571      127015
# 7                   EASTERN_ENGLISH_REGION    2573     2573      124430
# 8                SOUTH_WEST_ENGLISH_REGION    2574     2574      125094
#
#    UNIT_ID       CODE     HECTARES       AREA TYPE_CODE TYPE_COD0 DESCRIPT1  \
# 0    41423  E12000004  1581065.036  16738.106        SR      None      None
# 1    41428  E12000007   159462.494   2129.716        SR      None      None
# 2    41431  E12000002  1491493.427  75009.049        SR      None      None
# 3    41426  E12000005  1300382.887      0.000        SR      None      None
# 4    41430  E12000003  1556042.378  15220.120        SR      None      None
# 5    41421  E12000008  1940041.184  31274.395        SR      None      None
# 6    41422  E12000001   867553.985   7675.149        SR      None      None
# 7    41425  E12000006  1958705.316  45455.208        SR      None      None
# 8    41427  E12000009  2438569.751  53581.519        SR      None      None
#
#                     DESCRIPT0  \
# 0  STATISTICAL REPORTING AREA
# 1  STATISTICAL REPORTING AREA
# 2  STATISTICAL REPORTING AREA
# 3  STATISTICAL REPORTING AREA
# 4  STATISTICAL REPORTING AREA
# 5  STATISTICAL REPORTING AREA
# 6  STATISTICAL REPORTING AREA
# 7  STATISTICAL REPORTING AREA
# 8  STATISTICAL REPORTING AREA
#
#                                             geometry
# 0  POLYGON ((413673.997 400018.995, 413676.198 39...
# 1  POLYGON ((531024.595 200933.623, 531026.320 20...
# 2  POLYGON ((374209.550 348536.660, 374212.450 34...
# 3  POLYGON ((360408.943 340399.192, 360410.895 34...
# 4  POLYGON ((424875.080 379990.440, 424872.170 37...
# 5  MULTIPOLYGON (((490173.603 256107.999, 490234....
# 6  MULTIPOLYGON (((398217.260 657393.560, 398226....
# 7  MULTIPOLYGON (((647445.460 323359.390, 647443....
# 8  MULTIPOLYGON (((418659.802 242642.204, 418662....

# %% [markdown]
# ### Checking the region names

# %%
digimap_data_new["NAME"].unique()
# Out:
# array(['East Midlands English Region', 'London English Region',
#        'North West English Region', 'West Midlands English Region',
#        'Yorkshire and the Humber English Region',
#        'South East English Region', 'North East English Region',
#        'Eastern English Region', 'South West English Region'],
#       dtype=object)

# %%
#plotting how it looks like
digimap_data_new.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Filtering the hull city from the whole region

# %%
digimap_data_hull_df = digimap_data_new[digimap_data_new['NAME'] == 'Yorkshire and the Humber English Region']
digimap_data_hull_df
# Out:
#                                       NAME AREA_CODE      DESCRIPTIO  \
# 4  Yorkshire and the Humber English Region        ER  English Region
#
#                                  FILE_NAME  NUMBER  NUMBER0  POLYGON_ID  \
# 4  YORKSHIRE_AND_THE_HUMBER_ENGLISH_REGION    2569     2569      124954
#
#    UNIT_ID       CODE     HECTARES      AREA TYPE_CODE TYPE_COD0 DESCRIPT1  \
# 4    41430  E12000003  1556042.378  15220.12        SR      None      None
#
#                     DESCRIPT0  \
# 4  STATISTICAL REPORTING AREA
#
#                                             geometry
# 4  POLYGON ((424875.080 379990.440, 424872.170 37...

# %%
digimap_data_hull_df["centriod"] = digimap_data_hull_df["geometry"].centroid

# %%
digimap_data_hull_df
# Out:
#                                       NAME AREA_CODE      DESCRIPTIO  \
# 4  Yorkshire and the Humber English Region        ER  English Region
#
#                                  FILE_NAME  NUMBER  NUMBER0  POLYGON_ID  \
# 4  YORKSHIRE_AND_THE_HUMBER_ENGLISH_REGION    2569     2569      124954
#
#    UNIT_ID       CODE     HECTARES      AREA TYPE_CODE TYPE_COD0 DESCRIPT1  \
# 4    41430  E12000003  1556042.378  15220.12        SR      None      None
#
#                     DESCRIPT0  \
# 4  STATISTICAL REPORTING AREA
#
#                                             geometry  \
# 4  POLYGON ((424875.080 379990.440, 424872.170 37...
#
#                         centriod
# 4  POINT (451323.465 452107.366)

# %%
digimap_data_hull_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Merging all the data

# %% [markdown]
# ### Merging both boundary data , digimap data and osm data

# %%
# Writing a code that would measure all

target_crs = 'EPSG:4326'

hull_grid_data = hull_grid_data.to_crs(target_crs)
digimap_data_hull_df = digimap_data_hull_df.to_crs(target_crs)
osm_df = osm_df.to_crs(target_crs)
lsoa_hull = lsoa_hull.to_crs(target_crs)
# Join digimap data and  boundary data
digi_grid_data = gpd.sjoin(hull_grid_data, digimap_data_hull_df, how="inner", op="intersects")

# Drop the extra columns added by the spatial join
digi_grid_data = digi_grid_data.drop(columns=['index_right'])

# Join the result with osm data
digi_grid_osm = gpd.sjoin(osm_df, digi_grid_data, how="inner", op="intersects")

# Drop the extra columns added by the spatial join
digi_grid_osm = digi_grid_osm.drop(columns=['index_right'])

# Join the result with osm data
digi_grid_osm_lsoa = gpd.sjoin(digi_grid_osm, lsoa_hull  , how="inner", op="intersects")

# Drop the extra columns added by the spatial join
digi_grid_osm_lsoa = digi_grid_osm_lsoa.drop(columns=['index_right'])

digi_grid_osm_lsoa
# Out:
#            osm_id  code      fclass             name_left  \
# 22       14629351  7212      retail  Kingston Retail Park
# 22       14629351  7212      retail  Kingston Retail Park
# 45       22516155  7206    cemetery      Western Cemetery
# 45       22516155  7206    cemetery      Western Cemetery
# 45       22516155  7206    cemetery      Western Cemetery
# ...           ...   ...         ...                   ...
# 37894  1282989970  7201      forest                  None
# 37894  1282989970  7201      forest                  None
# 37895  1282990336  7208      meadow                  None
# 37895  1282990336  7208      meadow                  None
# 37917  1286686809  7204  industrial                  None
#
#                                                 geometry  \
# 22     POLYGON ((-0.34661 53.73929, -0.34448 53.73990...
# 22     POLYGON ((-0.34661 53.73929, -0.34448 53.73990...
# 45     POLYGON ((-0.38144 53.75207, -0.38094 53.75266...
# 45     POLYGON ((-0.38144 53.75207, -0.38094 53.75266...
# 45     POLYGON ((-0.38144 53.75207, -0.38094 53.75266...
# ...                                                  ...
# 37894  POLYGON ((-0.32666 53.75816, -0.32660 53.75825...
# 37894  POLYGON ((-0.32666 53.75816, -0.32660 53.75825...
# 37895  POLYGON ((-0.32329 53.75707, -0.32314 53.75805...
# 37895  POLYGON ((-0.32329 53.75707, -0.32314 53.75805...
# 37917  POLYGON ((-0.25459 53.77857, -0.25412 53.77857...
#
#                    centroid_left       CELLCODE  EOFORIGIN  NOFORIGIN  \
# 22     POINT (-0.34486 53.73896)  1kmE3640N3452    3640000    3452000
# 22     POINT (-0.34486 53.73896)  1kmE3641N3452    3641000    3452000
# 45     POINT (-0.37725 53.75197)  1kmE3638N3453    3638000    3453000
# 45     POINT (-0.37725 53.75197)  1kmE3639N3453    3639000    3453000
# 45     POINT (-0.37725 53.75197)  1kmE3638N3454    3638000    3454000
# ...                          ...            ...        ...        ...
# 37894  POINT (-0.32567 53.75762)  1kmE3642N3453    3642000    3453000
# 37894  POINT (-0.32567 53.75762)  1kmE3642N3454    3642000    3454000
# 37895  POINT (-0.32307 53.75764)  1kmE3642N3453    3642000    3453000
# 37895  POINT (-0.32307 53.75764)  1kmE3642N3454    3642000    3454000
# 37917  POINT (-0.25435 53.77843)  1kmE3647N3455    3647000    3455000
#
#                       centroid_right  ...      AREA TYPE_CODE TYPE_COD0  \
# 22     POINT (508740.154 428459.803)  ...  15220.12        SR      None
# 22     POINT (509727.360 428625.242)  ...  15220.12        SR      None
# 45     POINT (506598.469 429113.399)  ...  15220.12        SR      None
# 45     POINT (507585.676 429278.834)  ...  15220.12        SR      None
# 45     POINT (506431.187 430097.856)  ...  15220.12        SR      None
# ...                              ...  ...       ...       ...       ...
# 37894  POINT (510547.284 429775.170)  ...  15220.12        SR      None
# 37894  POINT (510379.990 430759.652)  ...  15220.12        SR      None
# 37895  POINT (510547.284 429775.170)  ...  15220.12        SR      None
# 37895  POINT (510379.990 430759.652)  ...  15220.12        SR      None
# 37917  POINT (515148.613 432571.526)  ...  15220.12        SR      None
#
#       DESCRIPT1                   DESCRIPT0                       centriod  \
# 22         None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 22         None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 45         None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 45         None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 45         None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# ...         ...                         ...                            ...
# 37894      None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 37894      None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 37895      None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 37895      None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
# 37917      None  STATISTICAL REPORTING AREA  POINT (451323.465 452107.366)
#
#         lsoa21cd                 lsoa21nm  \
# 22     E01012854  Kingston upon Hull 029C
# 22     E01012854  Kingston upon Hull 029C
# 45     E01012759  Kingston upon Hull 025C
# 45     E01012759  Kingston upon Hull 025C
# 45     E01012759  Kingston upon Hull 025C
# ...          ...                      ...
# 37894  E01012806  Kingston upon Hull 016B
# 37894  E01012806  Kingston upon Hull 016B
# 37895  E01012806  Kingston upon Hull 016B
# 37895  E01012806  Kingston upon Hull 016B
# 37917  E01012835  Kingston upon Hull 009B
#
#                                                label               name_right
# 22     E92000001E12000003E06000010E02002680E01012854  Kingston upon Hull 029C
# 22     E92000001E12000003E06000010E02002680E01012854  Kingston upon Hull 029C
# 45     E92000001E12000003E06000010E02002676E01012759  Kingston upon Hull 025C
# 45     E92000001E12000003E06000010E02002676E01012759  Kingston upon Hull 025C
# 45     E92000001E12000003E06000010E02002676E01012759  Kingston upon Hull 025C
# ...                                              ...                      ...
# 37894  E92000001E12000003E06000010E02002667E01012806  Kingston upon Hull 016B
# 37894  E92000001E12000003E06000010E02002667E01012806  Kingston upon Hull 016B
# 37895  E92000001E12000003E06000010E02002667E01012806  Kingston upon Hull 016B
# 37895  E92000001E12000003E06000010E02002667E01012806  Kingston upon Hull 016B
# 37917  E92000001E12000003E06000010E02002660E01012835  Kingston upon Hull 009B
#
# [3467 rows x 30 columns]

# %%
digi_grid_osm_lsoa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 3467 entries, 22 to 37917
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   osm_id          3467 non-null   object
#  1   code            3467 non-null   int64
#  2   fclass          3467 non-null   object
#  3   name_left       234 non-null    object
#  4   geometry        3467 non-null   geometry
#  5   centroid_left   3467 non-null   geometry
#  6   CELLCODE        3467 non-null   object
#  7   EOFORIGIN       3467 non-null   int64
#  8   NOFORIGIN       3467 non-null   int64
#  9   centroid_right  3467 non-null   geometry
#  10  NAME            3467 non-null   object
#  11  AREA_CODE       3467 non-null   object
#  12  DESCRIPTIO      3467 non-null   object
#  13  FILE_NAME       3467 non-null   object
#  14  NUMBER          3467 non-null   int64
#  15  NUMBER0         3467 non-null   int64
#  16  POLYGON_ID      3467 non-null   int64
#  17  UNIT_ID         3467 non-null   int64
#  18  CODE            3467 non-null   object
#  19  HECTARES        3467 non-null   float64
#  20  AREA            3467 non-null   float64
#  21  TYPE_CODE       3467 non-null   object
#  22  TYPE_COD0       0 non-null      object
#  23  DESCRIPT1       0 non-null      object
#  24  DESCRIPT0       3467 non-null   object
#  25  centriod        3467 non-null   geometry
#  26  lsoa21cd        3467 non-null   object
#  27  lsoa21nm        3467 non-null   object
#  28  label           3467 non-null   object
#  29  name_right      3467 non-null   object
# dtypes: float64(2), geometry(4), int64(7), object(17)
# memory usage: 839.7+ KB

# %%
digi_grid_osm.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Merging the census data ,  police data as a single data

# %%
# concatenating the three dataframes
census_police_df = pd.concat([police_df , census_df])
census_police_df
# Out:
#         Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 3001375                                 NaN                            NaN
# 3001390                                 NaN                            NaN
# 3001415                                 NaN                            NaN
# 3001416                                 NaN                            NaN
# 3001417                                 NaN                            NaN
# ...                                     ...                            ...
# 2855                              W01001695                   Cardiff 036B
# 2856                              W01001695                   Cardiff 036B
# 2857                              W01001695                   Cardiff 036B
# 2858                              W01001695                   Cardiff 036B
# 2859                              W01001695                   Cardiff 036B
#
#          Age (6 categories) Code Age (6 categories)  \
# 3001375                      NaN                NaN
# 3001390                      NaN                NaN
# 3001415                      NaN                NaN
# 3001416                      NaN                NaN
# 3001417                      NaN                NaN
# ...                          ...                ...
# 2855                         NaN                NaN
# 2856                         NaN                NaN
# 2857                         NaN                NaN
# 2858                         NaN                NaN
# 2859                         NaN                NaN
#
#          Economic activity status (7 categories) Code  \
# 3001375                                           NaN
# 3001390                                           NaN
# 3001415                                           NaN
# 3001416                                           NaN
# 3001417                                           NaN
# ...                                               ...
# 2855                                              NaN
# 2856                                              NaN
# 2857                                              NaN
# 2858                                              NaN
# 2859                                              NaN
#
#         Economic activity status (7 categories)  Sex (2 categories) Code  \
# 3001375                                     NaN                      NaN
# 3001390                                     NaN                      NaN
# 3001415                                     NaN                      NaN
# 3001416                                     NaN                      NaN
# 3001417                                     NaN                      NaN
# ...                                         ...                      ...
# 2855                                        NaN                      NaN
# 2856                                        NaN                      NaN
# 2857                                        NaN                      NaN
# 2858                                        NaN                      NaN
# 2859                                        NaN                      NaN
#
#         Sex (2 categories)  Observation  Ethnic group (20 categories) Code  \
# 3001375                NaN          NaN                                NaN
# 3001390                NaN          NaN                                NaN
# 3001415                NaN          NaN                                NaN
# 3001416                NaN          NaN                                NaN
# 3001417                NaN          NaN                                NaN
# ...                    ...          ...                                ...
# 2855                   NaN         29.0                               19.0
# 2856                   NaN         15.0                               19.0
# 2857                   NaN         27.0                               19.0
# 2858                   NaN         27.0                               19.0
# 2859                   NaN          0.0                               19.0
#
#          ...        Reported by       Falls within Longitude   Latitude  \
# 3001375  ...  Humberside Police  Humberside Police -0.335230  53.788680
# 3001390  ...  Humberside Police  Humberside Police -0.334913  53.794761
# 3001415  ...  Humberside Police  Humberside Police -0.321360  53.787408
# 3001416  ...  Humberside Police  Humberside Police -0.321537  53.786413
# 3001417  ...  Humberside Police  Humberside Police -0.322720  53.789863
# ...      ...                ...                ...       ...        ...
# 2855     ...                NaN                NaN       NaN        NaN
# 2856     ...                NaN                NaN       NaN        NaN
# 2857     ...                NaN                NaN       NaN        NaN
# 2858     ...                NaN                NaN       NaN        NaN
# 2859     ...                NaN                NaN       NaN        NaN
#
#                            Location  LSOA code                LSOA name  \
# 3001375  On or near Davidstow Close  E01012785  Kingston upon Hull 002B
# 3001390     On or near Malpas Close  E01012786  Kingston upon Hull 002C
# 3001415         On or near Hospital  E01012787  Kingston upon Hull 002D
# 3001416    On or near Shopping Area  E01012787  Kingston upon Hull 002D
# 3001417    On or near Dalwood Close  E01012787  Kingston upon Hull 002D
# ...                             ...        ...                      ...
# 2855                            NaN        NaN                      NaN
# 2856                            NaN        NaN                      NaN
# 2857                            NaN        NaN                      NaN
# 2858                            NaN        NaN                      NaN
# 2859                            NaN        NaN                      NaN
#
#          Crime type                          Last outcome category Context
# 3001375    Burglary  Investigation complete; no suspect identified     NaN
# 3001390    Burglary  Investigation complete; no suspect identified     NaN
# 3001415    Burglary  Investigation complete; no suspect identified     NaN
# 3001416    Burglary                    Unable to prosecute suspect     NaN
# 3001417    Burglary  Investigation complete; no suspect identified     NaN
# ...             ...                                            ...     ...
# 2855            NaN                                            NaN     NaN
# 2856            NaN                                            NaN     NaN
# 2857            NaN                                            NaN     NaN
# 2858            NaN                                            NaN     NaN
# 2859            NaN                                            NaN     NaN
#
# [3004824 rows x 25 columns]

# %%
lsoa21cd

# %%
# checking the data types
census_police_df.dtypes
# Out:
# Lower layer Super Output Areas Code              object
# Lower layer Super Output Areas                   object
# Age (6 categories) Code                         float64
# Age (6 categories)                               object
# Economic activity status (7 categories) Code    float64
# Economic activity status (7 categories)          object
# Sex (2 categories) Code                         float64
# Sex (2 categories)                               object
# Observation                                     float64
# Ethnic group (20 categories) Code               float64
# Ethnic group (20 categories)                     object
# Country of birth (13 categories) Code           float64
# Country of birth (13 categories)                 object
# Crime ID                                         object
# Month                                            object
# Reported by                                      object
# Falls within                                     object
# Longitude                                       float64
# Latitude                                        float64
# Location                                         object
# LSOA code                                        object
# LSOA name                                        object
# Crime type                                       object
# Last outcome category                            object
# Context                                         float64
# dtype: object

# %% [markdown]
# ### Merging all the data together as a crime data

# %%
# Step 3: Merge the GeoDataFrame and the pandas DataFrame on the common key
lsoa_merged_gdf = lsoa_hull.merge(lsoa_hull_df, on='lsoa21nm')

# Step 4: Save the merged GeoDataFrame to a new shapefile
lsoa_merged_gdf.to_file('./data/lsoa/lsoa_gdf.shp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Step 3: Merge the GeoDataFrame and the pandas DataFrame on the common key
# ----> 2 lsoa_merged_gdf = lsoa_hull.merge(lsoa_hull_df, on='lsoa21nm')
#       4 # Step 4: Save the merged GeoDataFrame to a new shapefile
#       5 lsoa_merged_gdf.to_file('./data/lsoa/lsoa_gdf.shp')
#
# NameError: name 'lsoa_hull_df' is not defined
